# %% [markdown]
# # Model Interpretation Methods

# %% [markdown]
# Welcome to the final assignment of course 3! In this assignment we will focus on the interpretation of machine learning and deep learning models. Using the techniques we've learned this week we'll revisit some of the models we've built throughout the course and try to understand a little more about what they're doing.
#
# In this assignment you'll use various methods to interpret different types of machine learning models. In particular, you'll learn about the following topics:
#
# - Interpreting Deep Learning Models
#     - Understanding output using GradCAMs
# - Feature Importance in Machine Learning
#     - Permutation Method
#     - SHAP Values
#
# Let's get started.

# %% [markdown]
# ### This assignment covers the folowing topics:
#
# - [1. Interpreting Deep Learning Models](#1)
#   - [1.1 GradCAM](#1-1)
#     - [1.1.1 Getting Intermediate Layers](#1-1-1)
#     - [1.1.2 Getting Gradients](#1-1-2)
#     - [1.1.3 Implementing GradCAM](#1-1-3)
#       - [Exercise 1](#ex-01)
#     - [1.1.4 Using GradCAM to Visualize Multiple Labels](#1-1-4)
#       - [Exercise 2](#ex-02)
# - [2. Feature Importance in Machine Learning](#2)
#   - [2.1 Permuation Method for Feature Importance](#2-1)
#     - [2.1.1 Implementing Permutation](#2-1-1)
#       - [Exercise 3](#ex-03)
#     - [2.1.2 Implementing Importance](#2-1-2)
#       - [Exercise 4](#ex-04)
#     - [2.1.3 Computing our Feature Importance](#2-1-3)
#   - [2.2 Shapley Values for Random Forests](#2-2)
#     - [2.2.1 Visualizing Feature Importance on Specific Individuals](#2-2-1)
#     - [2.2.2 Visualizing Feature Importance on Aggregate](#2-2-2)
#     - [2.2.3 Visualizing Interactions between Features](#2-2-3)

# %% [markdown]
# ## Packages
#
# We'll first import the necessary packages for this assignment.
#
# - `keras`: we'll use this framework to interact with our deep learning model
# - `matplotlib`: standard plotting library
# - `pandas`: we'll use this to manipulate data
# - `numpy`: standard python library for numerical operations
# - `cv2`: library that contains convenience functions for image processing
# - `sklearn`: standard machine learning library
# - `lifelines`: we'll use their implementation of the c-index
# - `shap`: library for interpreting and visualizing machine learning models using shapley values

# %%
import keras
from keras import backend as K
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import cv2
import sklearn
import lifelines
import shap


from util import *

# This sets a common size for all the figures we will draw.
plt.rcParams['figure.figsize'] = [10, 7]
# Out:
# Using TensorFlow backend.

# %% [markdown]
# <a name="1"></a>
# ## 1 Interpreting Deep Learning Models
#
# To start, let's try understanding our X-ray diagnostic model from Course 1 Week 1. Run the next cell to load in the model (it should take a few seconds to complete).

# %%
model = load_C3M3_model()
# Out:
# Got loss weights
# Loaded DenseNet
# Added layers
# Compiled Model
# Loaded Weights

# %% [markdown]
# Let's load in an X-ray image to develop on. Run the next cell to load and show the image.

# %%
IMAGE_DIR = 'nih_new/images-small/'
df = pd.read_csv("nih_new/train-small.csv")
im_path = IMAGE_DIR + '00025288_001.png' 
x = load_image(im_path, df, preprocess=False)
plt.imshow(x, cmap = 'gray')
plt.show()

# %% [markdown]
# Next, let's get our predictions. Before we plug the image into our model, we have to normalize it. Run the next cell to compute the mean and standard deviation of the images in our training set.

# %%
mean, std = get_mean_std_per_batch(df)

# %% [markdown]
# Now we are ready to normalize and run the image through our model to get predictions.

# %%
labels = ['Cardiomegaly', 'Emphysema', 'Effusion', 'Hernia', 'Infiltration', 'Mass', 'Nodule', 'Atelectasis',
              'Pneumothorax', 'Pleural_Thickening', 'Pneumonia', 'Fibrosis', 'Edema', 'Consolidation']

processed_image = load_image_normalize(im_path, mean, std)
preds = model.predict(processed_image)
pred_df = pd.DataFrame(preds, columns = labels)
pred_df.loc[0, :].plot.bar()
plt.title("Predictions")
plt.show()

# %% [markdown]
# We see, for example, that the model predicts Mass (abnormal spot or area in the lungs that are more than 3 centimeters) with high probability. Indeed, this patient was diagnosed with mass. However, we don't know where the model is looking when it's making its own diagnosis. To gain more insight into what the model is looking at, we can use GradCAMs.

# %% [markdown]
# <a name="1-1"></a>
# ### 1.1 GradCAM

# %% [markdown]
# GradCAM is a technique to visualize the impact of each region of an image on a specific output for a Convolutional Neural Network model. Through GradCAM, we can generate a heatmap by computing gradients of the specific class scores we are interested in visualizing.

# %% [markdown]
# <a name="1-1-1"></a>
# #### 1.1.1 Getting Intermediate Layers
#
# Perhaps the most complicated part of computing GradCAM is accessing intermediate activations in our deep learning model and computing gradients with respect to the class output. Now we'll go over one pattern to accomplish this, which you can use when implementing GradCAM.
#
# In order to understand how to access intermediate layers in a computation, first let's see the layers that our model is composed of. This can be done by calling Keras convenience function `model.summary()`. Do this in the cell below.

# %%
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, None, None, 3 0
# __________________________________________________________________________________________________
# zero_padding2d_1 (ZeroPadding2D (None, None, None, 3 0           input_1[0][0]
# __________________________________________________________________________________________________
# conv1/conv (Conv2D)             (None, None, None, 6 9408        zero_padding2d_1[0][0]
# __________________________________________________________________________________________________
# conv1/bn (BatchNormalization)   (None, None, None, 6 256         conv1/conv[0][0]
# __________________________________________________________________________________________________
# conv1/relu (Activation)         (None, None, None, 6 0           conv1/bn[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_2 (ZeroPadding2D (None, None, None, 6 0           conv1/relu[0][0]
# __________________________________________________________________________________________________
# pool1 (MaxPooling2D)            (None, None, None, 6 0           zero_padding2d_2[0][0]
# __________________________________________________________________________________________________
# conv2_block1_0_bn (BatchNormali (None, None, None, 6 256         pool1[0][0]
# __________________________________________________________________________________________________
# conv2_block1_0_relu (Activation (None, None, None, 6 0           conv2_block1_0_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_conv (Conv2D)    (None, None, None, 1 8192        conv2_block1_0_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_bn (BatchNormali (None, None, None, 1 512         conv2_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_relu (Activation (None, None, None, 1 0           conv2_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_conv (Conv2D)    (None, None, None, 3 36864       conv2_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_concat (Concatenat (None, None, None, 9 0           pool1[0][0]
#                                                                  conv2_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_0_bn (BatchNormali (None, None, None, 9 384         conv2_block1_concat[0][0]
# __________________________________________________________________________________________________
# conv2_block2_0_relu (Activation (None, None, None, 9 0           conv2_block2_0_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_conv (Conv2D)    (None, None, None, 1 12288       conv2_block2_0_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_bn (BatchNormali (None, None, None, 1 512         conv2_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_relu (Activation (None, None, None, 1 0           conv2_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_conv (Conv2D)    (None, None, None, 3 36864       conv2_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_concat (Concatenat (None, None, None, 1 0           conv2_block1_concat[0][0]
#                                                                  conv2_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_0_bn (BatchNormali (None, None, None, 1 512         conv2_block2_concat[0][0]
# __________________________________________________________________________________________________
# conv2_block3_0_relu (Activation (None, None, None, 1 0           conv2_block3_0_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_conv (Conv2D)    (None, None, None, 1 16384       conv2_block3_0_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_bn (BatchNormali (None, None, None, 1 512         conv2_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_relu (Activation (None, None, None, 1 0           conv2_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_conv (Conv2D)    (None, None, None, 3 36864       conv2_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block3_concat (Concatenat (None, None, None, 1 0           conv2_block2_concat[0][0]
#                                                                  conv2_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block4_0_bn (BatchNormali (None, None, None, 1 640         conv2_block3_concat[0][0]
# __________________________________________________________________________________________________
# conv2_block4_0_relu (Activation (None, None, None, 1 0           conv2_block4_0_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block4_1_conv (Conv2D)    (None, None, None, 1 20480       conv2_block4_0_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block4_1_bn (BatchNormali (None, None, None, 1 512         conv2_block4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block4_1_relu (Activation (None, None, None, 1 0           conv2_block4_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block4_2_conv (Conv2D)    (None, None, None, 3 36864       conv2_block4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block4_concat (Concatenat (None, None, None, 1 0           conv2_block3_concat[0][0]
#                                                                  conv2_block4_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block5_0_bn (BatchNormali (None, None, None, 1 768         conv2_block4_concat[0][0]
# __________________________________________________________________________________________________
# conv2_block5_0_relu (Activation (None, None, None, 1 0           conv2_block5_0_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block5_1_conv (Conv2D)    (None, None, None, 1 24576       conv2_block5_0_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block5_1_bn (BatchNormali (None, None, None, 1 512         conv2_block5_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block5_1_relu (Activation (None, None, None, 1 0           conv2_block5_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block5_2_conv (Conv2D)    (None, None, None, 3 36864       conv2_block5_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block5_concat (Concatenat (None, None, None, 2 0           conv2_block4_concat[0][0]
#                                                                  conv2_block5_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block6_0_bn (BatchNormali (None, None, None, 2 896         conv2_block5_concat[0][0]
# __________________________________________________________________________________________________
# conv2_block6_0_relu (Activation (None, None, None, 2 0           conv2_block6_0_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block6_1_conv (Conv2D)    (None, None, None, 1 28672       conv2_block6_0_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block6_1_bn (BatchNormali (None, None, None, 1 512         conv2_block6_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block6_1_relu (Activation (None, None, None, 1 0           conv2_block6_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block6_2_conv (Conv2D)    (None, None, None, 3 36864       conv2_block6_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block6_concat (Concatenat (None, None, None, 2 0           conv2_block5_concat[0][0]
#                                                                  conv2_block6_2_conv[0][0]
# __________________________________________________________________________________________________
# pool2_bn (BatchNormalization)   (None, None, None, 2 1024        conv2_block6_concat[0][0]
# __________________________________________________________________________________________________
# pool2_relu (Activation)         (None, None, None, 2 0           pool2_bn[0][0]
# __________________________________________________________________________________________________
# pool2_conv (Conv2D)             (None, None, None, 1 32768       pool2_relu[0][0]
# __________________________________________________________________________________________________
# pool2_pool (AveragePooling2D)   (None, None, None, 1 0           pool2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_0_bn (BatchNormali (None, None, None, 1 512         pool2_pool[0][0]
# __________________________________________________________________________________________________
# conv3_block1_0_relu (Activation (None, None, None, 1 0           conv3_block1_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_conv (Conv2D)    (None, None, None, 1 16384       conv3_block1_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_bn (BatchNormali (None, None, None, 1 512         conv3_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_relu (Activation (None, None, None, 1 0           conv3_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_conv (Conv2D)    (None, None, None, 3 36864       conv3_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_concat (Concatenat (None, None, None, 1 0           pool2_pool[0][0]
#                                                                  conv3_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_0_bn (BatchNormali (None, None, None, 1 640         conv3_block1_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block2_0_relu (Activation (None, None, None, 1 0           conv3_block2_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_conv (Conv2D)    (None, None, None, 1 20480       conv3_block2_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_bn (BatchNormali (None, None, None, 1 512         conv3_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_relu (Activation (None, None, None, 1 0           conv3_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_conv (Conv2D)    (None, None, None, 3 36864       conv3_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block2_concat (Concatenat (None, None, None, 1 0           conv3_block1_concat[0][0]
#                                                                  conv3_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_0_bn (BatchNormali (None, None, None, 1 768         conv3_block2_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block3_0_relu (Activation (None, None, None, 1 0           conv3_block3_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_conv (Conv2D)    (None, None, None, 1 24576       conv3_block3_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_bn (BatchNormali (None, None, None, 1 512         conv3_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_relu (Activation (None, None, None, 1 0           conv3_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_conv (Conv2D)    (None, None, None, 3 36864       conv3_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block3_concat (Concatenat (None, None, None, 2 0           conv3_block2_concat[0][0]
#                                                                  conv3_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_0_bn (BatchNormali (None, None, None, 2 896         conv3_block3_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block4_0_relu (Activation (None, None, None, 2 0           conv3_block4_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_conv (Conv2D)    (None, None, None, 1 28672       conv3_block4_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_bn (BatchNormali (None, None, None, 1 512         conv3_block4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_relu (Activation (None, None, None, 1 0           conv3_block4_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_conv (Conv2D)    (None, None, None, 3 36864       conv3_block4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block4_concat (Concatenat (None, None, None, 2 0           conv3_block3_concat[0][0]
#                                                                  conv3_block4_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block5_0_bn (BatchNormali (None, None, None, 2 1024        conv3_block4_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block5_0_relu (Activation (None, None, None, 2 0           conv3_block5_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block5_1_conv (Conv2D)    (None, None, None, 1 32768       conv3_block5_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block5_1_bn (BatchNormali (None, None, None, 1 512         conv3_block5_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block5_1_relu (Activation (None, None, None, 1 0           conv3_block5_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block5_2_conv (Conv2D)    (None, None, None, 3 36864       conv3_block5_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block5_concat (Concatenat (None, None, None, 2 0           conv3_block4_concat[0][0]
#                                                                  conv3_block5_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block6_0_bn (BatchNormali (None, None, None, 2 1152        conv3_block5_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block6_0_relu (Activation (None, None, None, 2 0           conv3_block6_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block6_1_conv (Conv2D)    (None, None, None, 1 36864       conv3_block6_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block6_1_bn (BatchNormali (None, None, None, 1 512         conv3_block6_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block6_1_relu (Activation (None, None, None, 1 0           conv3_block6_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block6_2_conv (Conv2D)    (None, None, None, 3 36864       conv3_block6_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block6_concat (Concatenat (None, None, None, 3 0           conv3_block5_concat[0][0]
#                                                                  conv3_block6_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block7_0_bn (BatchNormali (None, None, None, 3 1280        conv3_block6_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block7_0_relu (Activation (None, None, None, 3 0           conv3_block7_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block7_1_conv (Conv2D)    (None, None, None, 1 40960       conv3_block7_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block7_1_bn (BatchNormali (None, None, None, 1 512         conv3_block7_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block7_1_relu (Activation (None, None, None, 1 0           conv3_block7_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block7_2_conv (Conv2D)    (None, None, None, 3 36864       conv3_block7_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block7_concat (Concatenat (None, None, None, 3 0           conv3_block6_concat[0][0]
#                                                                  conv3_block7_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block8_0_bn (BatchNormali (None, None, None, 3 1408        conv3_block7_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block8_0_relu (Activation (None, None, None, 3 0           conv3_block8_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block8_1_conv (Conv2D)    (None, None, None, 1 45056       conv3_block8_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block8_1_bn (BatchNormali (None, None, None, 1 512         conv3_block8_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block8_1_relu (Activation (None, None, None, 1 0           conv3_block8_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block8_2_conv (Conv2D)    (None, None, None, 3 36864       conv3_block8_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block8_concat (Concatenat (None, None, None, 3 0           conv3_block7_concat[0][0]
#                                                                  conv3_block8_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block9_0_bn (BatchNormali (None, None, None, 3 1536        conv3_block8_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block9_0_relu (Activation (None, None, None, 3 0           conv3_block9_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block9_1_conv (Conv2D)    (None, None, None, 1 49152       conv3_block9_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block9_1_bn (BatchNormali (None, None, None, 1 512         conv3_block9_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block9_1_relu (Activation (None, None, None, 1 0           conv3_block9_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block9_2_conv (Conv2D)    (None, None, None, 3 36864       conv3_block9_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block9_concat (Concatenat (None, None, None, 4 0           conv3_block8_concat[0][0]
#                                                                  conv3_block9_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block10_0_bn (BatchNormal (None, None, None, 4 1664        conv3_block9_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block10_0_relu (Activatio (None, None, None, 4 0           conv3_block10_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block10_1_conv (Conv2D)   (None, None, None, 1 53248       conv3_block10_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block10_1_bn (BatchNormal (None, None, None, 1 512         conv3_block10_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block10_1_relu (Activatio (None, None, None, 1 0           conv3_block10_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block10_2_conv (Conv2D)   (None, None, None, 3 36864       conv3_block10_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block10_concat (Concatena (None, None, None, 4 0           conv3_block9_concat[0][0]
#                                                                  conv3_block10_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block11_0_bn (BatchNormal (None, None, None, 4 1792        conv3_block10_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block11_0_relu (Activatio (None, None, None, 4 0           conv3_block11_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block11_1_conv (Conv2D)   (None, None, None, 1 57344       conv3_block11_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block11_1_bn (BatchNormal (None, None, None, 1 512         conv3_block11_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block11_1_relu (Activatio (None, None, None, 1 0           conv3_block11_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block11_2_conv (Conv2D)   (None, None, None, 3 36864       conv3_block11_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block11_concat (Concatena (None, None, None, 4 0           conv3_block10_concat[0][0]
#                                                                  conv3_block11_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block12_0_bn (BatchNormal (None, None, None, 4 1920        conv3_block11_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block12_0_relu (Activatio (None, None, None, 4 0           conv3_block12_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block12_1_conv (Conv2D)   (None, None, None, 1 61440       conv3_block12_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block12_1_bn (BatchNormal (None, None, None, 1 512         conv3_block12_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block12_1_relu (Activatio (None, None, None, 1 0           conv3_block12_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block12_2_conv (Conv2D)   (None, None, None, 3 36864       conv3_block12_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block12_concat (Concatena (None, None, None, 5 0           conv3_block11_concat[0][0]
#                                                                  conv3_block12_2_conv[0][0]
# __________________________________________________________________________________________________
# pool3_bn (BatchNormalization)   (None, None, None, 5 2048        conv3_block12_concat[0][0]
# __________________________________________________________________________________________________
# pool3_relu (Activation)         (None, None, None, 5 0           pool3_bn[0][0]
# __________________________________________________________________________________________________
# pool3_conv (Conv2D)             (None, None, None, 2 131072      pool3_relu[0][0]
# __________________________________________________________________________________________________
# pool3_pool (AveragePooling2D)   (None, None, None, 2 0           pool3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_0_bn (BatchNormali (None, None, None, 2 1024        pool3_pool[0][0]
# __________________________________________________________________________________________________
# conv4_block1_0_relu (Activation (None, None, None, 2 0           conv4_block1_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_conv (Conv2D)    (None, None, None, 1 32768       conv4_block1_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_bn (BatchNormali (None, None, None, 1 512         conv4_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_relu (Activation (None, None, None, 1 0           conv4_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_conv (Conv2D)    (None, None, None, 3 36864       conv4_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_concat (Concatenat (None, None, None, 2 0           pool3_pool[0][0]
#                                                                  conv4_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_0_bn (BatchNormali (None, None, None, 2 1152        conv4_block1_concat[0][0]
# __________________________________________________________________________________________________
# conv4_block2_0_relu (Activation (None, None, None, 2 0           conv4_block2_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_conv (Conv2D)    (None, None, None, 1 36864       conv4_block2_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_bn (BatchNormali (None, None, None, 1 512         conv4_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_relu (Activation (None, None, None, 1 0           conv4_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_conv (Conv2D)    (None, None, None, 3 36864       conv4_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block2_concat (Concatenat (None, None, None, 3 0           conv4_block1_concat[0][0]
#                                                                  conv4_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_0_bn (BatchNormali (None, None, None, 3 1280        conv4_block2_concat[0][0]
# __________________________________________________________________________________________________
# conv4_block3_0_relu (Activation (None, None, None, 3 0           conv4_block3_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_conv (Conv2D)    (None, None, None, 1 40960       conv4_block3_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_bn (BatchNormali (None, None, None, 1 512         conv4_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_relu (Activation (None, None, None, 1 0           conv4_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_conv (Conv2D)    (None, None, None, 3 36864       conv4_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block3_concat (Concatenat (None, None, None, 3 0           conv4_block2_concat[0][0]
#                                                                  conv4_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_0_bn (BatchNormali (None, None, None, 3 1408        conv4_block3_concat[0][0]
# __________________________________________________________________________________________________
# conv4_block4_0_relu (Activation (None, None, None, 3 0           conv4_block4_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_conv (Conv2D)    (None, None, None, 1 45056       conv4_block4_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_bn (BatchNormali (None, None, None, 1 512         conv4_block4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_relu (Activation (None, None, None, 1 0           conv4_block4_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_conv (Conv2D)    (None, None, None, 3 36864       conv4_block4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block4_concat (Concatenat (None, None, None, 3 0           conv4_block3_concat[0][0]
#                                                                  conv4_block4_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_0_bn (BatchNormali (None, None, None, 3 1536        conv4_block4_concat[0][0]
# __________________________________________________________________________________________________
# conv4_block5_0_relu (Activation (None, None, None, 3 0           conv4_block5_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_conv (Conv2D)    (None, None, None, 1 49152       conv4_block5_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_bn (BatchNormali (None, None, None, 1 512         conv4_block5_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_relu (Activation (None, None, None, 1 0           conv4_block5_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_conv (Conv2D)    (None, None, None, 3 36864       conv4_block5_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block5_concat (Concatenat (None, None, None, 4 0           conv4_block4_concat[0][0]
#                                                                  conv4_block5_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_0_bn (BatchNormali (None, None, None, 4 1664        conv4_block5_concat[0][0]
# __________________________________________________________________________________________________
# conv4_block6_0_relu (Activation (None, None, None, 4 0           conv4_block6_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_conv (Conv2D)    (None, None, None, 1 53248       conv4_block6_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_bn (BatchNormali (None, None, None, 1 512         conv4_block6_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_relu (Activation (None, None, None, 1 0           conv4_block6_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_conv (Conv2D)    (None, None, None, 3 36864       conv4_block6_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block6_concat (Concatenat (None, None, None, 4 0           conv4_block5_concat[0][0]
#                                                                  conv4_block6_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block7_0_bn (BatchNormali (None, None, None, 4 1792        conv4_block6_concat[0][0]
# __________________________________________________________________________________________________
# conv4_block7_0_relu (Activation (None, None, None, 4 0           conv4_block7_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block7_1_conv (Conv2D)    (None, None, None, 1 57344       conv4_block7_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block7_1_bn (BatchNormali (None, None, None, 1 512         conv4_block7_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block7_1_relu (Activation (None, None, None, 1 0           conv4_block7_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block7_2_conv (Conv2D)    (None, None, None, 3 36864       conv4_block7_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block7_concat (Concatenat (None, None, None, 4 0           conv4_block6_concat[0][0]
#                                                                  conv4_block7_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block8_0_bn (BatchNormali (None, None, None, 4 1920        conv4_block7_concat[0][0]
# __________________________________________________________________________________________________
# conv4_block8_0_relu (Activation (None, None, None, 4 0           conv4_block8_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block8_1_conv (Conv2D)    (None, None, None, 1 61440       conv4_block8_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block8_1_bn (BatchNormali (None, None, None, 1 512         conv4_block8_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block8_1_relu (Activation (None, None, None, 1 0           conv4_block8_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block8_2_conv (Conv2D)    (None, None, None, 3 36864       conv4_block8_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block8_concat (Concatenat (None, None, None, 5 0           conv4_block7_concat[0][0]
#                                                                  conv4_block8_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block9_0_bn (BatchNormali (None, None, None, 5 2048        conv4_block8_concat[0][0]
# __________________________________________________________________________________________________
# conv4_block9_0_relu (Activation (None, None, None, 5 0           conv4_block9_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block9_1_conv (Conv2D)    (None, None, None, 1 65536       conv4_block9_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block9_1_bn (BatchNormali (None, None, None, 1 512         conv4_block9_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block9_1_relu (Activation (None, None, None, 1 0           conv4_block9_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block9_2_conv (Conv2D)    (None, None, None, 3 36864       conv4_block9_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block9_concat (Concatenat (None, None, None, 5 0           conv4_block8_concat[0][0]
#                                                                  conv4_block9_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block10_0_bn (BatchNormal (None, None, None, 5 2176        conv4_block9_concat[0][0]
# __________________________________________________________________________________________________
# conv4_block10_0_relu (Activatio (None, None, None, 5 0           conv4_block10_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block10_1_conv (Conv2D)   (None, None, None, 1 69632       conv4_block10_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block10_1_bn (BatchNormal (None, None, None, 1 512         conv4_block10_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block10_1_relu (Activatio (None, None, None, 1 0           conv4_block10_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block10_2_conv (Conv2D)   (None, None, None, 3 36864       conv4_block10_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block10_concat (Concatena (None, None, None, 5 0           conv4_block9_concat[0][0]
#                                                                  conv4_block10_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block11_0_bn (BatchNormal (None, None, None, 5 2304        conv4_block10_concat[0][0]
# __________________________________________________________________________________________________
# conv4_block11_0_relu (Activatio (None, None, None, 5 0           conv4_block11_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block11_1_conv (Conv2D)   (None, None, None, 1 73728       conv4_block11_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block11_1_bn (BatchNormal (None, None, None, 1 512         conv4_block11_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block11_1_relu (Activatio (None, None, None, 1 0           conv4_block11_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block11_2_conv (Conv2D)   (None, None, None, 3 36864       conv4_block11_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block11_concat (Concatena (None, None, None, 6 0           conv4_block10_concat[0][0]
#                                                                  conv4_block11_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block12_0_bn (BatchNormal (None, None, None, 6 2432        conv4_block11_concat[0][0]
# __________________________________________________________________________________________________
# conv4_block12_0_relu (Activatio (None, None, None, 6 0           conv4_block12_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block12_1_conv (Conv2D)   (None, None, None, 1 77824       conv4_block12_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block12_1_bn (BatchNormal (None, None, None, 1 512         conv4_block12_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block12_1_relu (Activatio (None, None, None, 1 0           conv4_block12_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block12_2_conv (Conv2D)   (None, None, None, 3 36864       conv4_block12_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block12_concat (Concatena (None, None, None, 6 0           conv4_block11_concat[0][0]
#                                                                  conv4_block12_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block13_0_bn (BatchNormal (None, None, None, 6 2560        conv4_block12_concat[0][0]
# ...
# conv5_block6_concat (Concatenat (None, None, None, 7 0           conv5_block5_concat[0][0]
#                                                                  conv5_block6_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block7_0_bn (BatchNormali (None, None, None, 7 2816        conv5_block6_concat[0][0]
# __________________________________________________________________________________________________
# conv5_block7_0_relu (Activation (None, None, None, 7 0           conv5_block7_0_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block7_1_conv (Conv2D)    (None, None, None, 1 90112       conv5_block7_0_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block7_1_bn (BatchNormali (None, None, None, 1 512         conv5_block7_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block7_1_relu (Activation (None, None, None, 1 0           conv5_block7_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block7_2_conv (Conv2D)    (None, None, None, 3 36864       conv5_block7_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block7_concat (Concatenat (None, None, None, 7 0           conv5_block6_concat[0][0]
#                                                                  conv5_block7_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block8_0_bn (BatchNormali (None, None, None, 7 2944        conv5_block7_concat[0][0]
# __________________________________________________________________________________________________
# conv5_block8_0_relu (Activation (None, None, None, 7 0           conv5_block8_0_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block8_1_conv (Conv2D)    (None, None, None, 1 94208       conv5_block8_0_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block8_1_bn (BatchNormali (None, None, None, 1 512         conv5_block8_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block8_1_relu (Activation (None, None, None, 1 0           conv5_block8_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block8_2_conv (Conv2D)    (None, None, None, 3 36864       conv5_block8_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block8_concat (Concatenat (None, None, None, 7 0           conv5_block7_concat[0][0]
#                                                                  conv5_block8_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block9_0_bn (BatchNormali (None, None, None, 7 3072        conv5_block8_concat[0][0]
# __________________________________________________________________________________________________
# conv5_block9_0_relu (Activation (None, None, None, 7 0           conv5_block9_0_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block9_1_conv (Conv2D)    (None, None, None, 1 98304       conv5_block9_0_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block9_1_bn (BatchNormali (None, None, None, 1 512         conv5_block9_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block9_1_relu (Activation (None, None, None, 1 0           conv5_block9_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block9_2_conv (Conv2D)    (None, None, None, 3 36864       conv5_block9_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block9_concat (Concatenat (None, None, None, 8 0           conv5_block8_concat[0][0]
#                                                                  conv5_block9_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block10_0_bn (BatchNormal (None, None, None, 8 3200        conv5_block9_concat[0][0]
# __________________________________________________________________________________________________
# conv5_block10_0_relu (Activatio (None, None, None, 8 0           conv5_block10_0_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block10_1_conv (Conv2D)   (None, None, None, 1 102400      conv5_block10_0_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block10_1_bn (BatchNormal (None, None, None, 1 512         conv5_block10_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block10_1_relu (Activatio (None, None, None, 1 0           conv5_block10_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block10_2_conv (Conv2D)   (None, None, None, 3 36864       conv5_block10_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block10_concat (Concatena (None, None, None, 8 0           conv5_block9_concat[0][0]
#                                                                  conv5_block10_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block11_0_bn (BatchNormal (None, None, None, 8 3328        conv5_block10_concat[0][0]
# __________________________________________________________________________________________________
# conv5_block11_0_relu (Activatio (None, None, None, 8 0           conv5_block11_0_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block11_1_conv (Conv2D)   (None, None, None, 1 106496      conv5_block11_0_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block11_1_bn (BatchNormal (None, None, None, 1 512         conv5_block11_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block11_1_relu (Activatio (None, None, None, 1 0           conv5_block11_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block11_2_conv (Conv2D)   (None, None, None, 3 36864       conv5_block11_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block11_concat (Concatena (None, None, None, 8 0           conv5_block10_concat[0][0]
#                                                                  conv5_block11_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block12_0_bn (BatchNormal (None, None, None, 8 3456        conv5_block11_concat[0][0]
# __________________________________________________________________________________________________
# conv5_block12_0_relu (Activatio (None, None, None, 8 0           conv5_block12_0_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block12_1_conv (Conv2D)   (None, None, None, 1 110592      conv5_block12_0_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block12_1_bn (BatchNormal (None, None, None, 1 512         conv5_block12_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block12_1_relu (Activatio (None, None, None, 1 0           conv5_block12_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block12_2_conv (Conv2D)   (None, None, None, 3 36864       conv5_block12_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block12_concat (Concatena (None, None, None, 8 0           conv5_block11_concat[0][0]
#                                                                  conv5_block12_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block13_0_bn (BatchNormal (None, None, None, 8 3584        conv5_block12_concat[0][0]
# __________________________________________________________________________________________________
# conv5_block13_0_relu (Activatio (None, None, None, 8 0           conv5_block13_0_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block13_1_conv (Conv2D)   (None, None, None, 1 114688      conv5_block13_0_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block13_1_bn (BatchNormal (None, None, None, 1 512         conv5_block13_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block13_1_relu (Activatio (None, None, None, 1 0           conv5_block13_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block13_2_conv (Conv2D)   (None, None, None, 3 36864       conv5_block13_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block13_concat (Concatena (None, None, None, 9 0           conv5_block12_concat[0][0]
#                                                                  conv5_block13_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block14_0_bn (BatchNormal (None, None, None, 9 3712        conv5_block13_concat[0][0]
# __________________________________________________________________________________________________
# conv5_block14_0_relu (Activatio (None, None, None, 9 0           conv5_block14_0_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block14_1_conv (Conv2D)   (None, None, None, 1 118784      conv5_block14_0_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block14_1_bn (BatchNormal (None, None, None, 1 512         conv5_block14_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block14_1_relu (Activatio (None, None, None, 1 0           conv5_block14_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block14_2_conv (Conv2D)   (None, None, None, 3 36864       conv5_block14_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block14_concat (Concatena (None, None, None, 9 0           conv5_block13_concat[0][0]
#                                                                  conv5_block14_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block15_0_bn (BatchNormal (None, None, None, 9 3840        conv5_block14_concat[0][0]
# __________________________________________________________________________________________________
# conv5_block15_0_relu (Activatio (None, None, None, 9 0           conv5_block15_0_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block15_1_conv (Conv2D)   (None, None, None, 1 122880      conv5_block15_0_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block15_1_bn (BatchNormal (None, None, None, 1 512         conv5_block15_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block15_1_relu (Activatio (None, None, None, 1 0           conv5_block15_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block15_2_conv (Conv2D)   (None, None, None, 3 36864       conv5_block15_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block15_concat (Concatena (None, None, None, 9 0           conv5_block14_concat[0][0]
#                                                                  conv5_block15_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block16_0_bn (BatchNormal (None, None, None, 9 3968        conv5_block15_concat[0][0]
# __________________________________________________________________________________________________
# conv5_block16_0_relu (Activatio (None, None, None, 9 0           conv5_block16_0_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block16_1_conv (Conv2D)   (None, None, None, 1 126976      conv5_block16_0_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block16_1_bn (BatchNormal (None, None, None, 1 512         conv5_block16_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block16_1_relu (Activatio (None, None, None, 1 0           conv5_block16_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block16_2_conv (Conv2D)   (None, None, None, 3 36864       conv5_block16_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block16_concat (Concatena (None, None, None, 1 0           conv5_block15_concat[0][0]
#                                                                  conv5_block16_2_conv[0][0]
# __________________________________________________________________________________________________
# bn (BatchNormalization)         (None, None, None, 1 4096        conv5_block16_concat[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_1 (Glo (None, 1024)         0           bn[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 14)           14350       global_average_pooling2d_1[0][0]
# ==================================================================================================
# Total params: 7,051,854
# Trainable params: 6,968,206
# Non-trainable params: 83,648
# __________________________________________________________________________________________________

# %% [markdown]
# There are a lot of layers, but typically we'll only be extracting one of the last few. Remember that the last few layers usually have more abstract information. To access a layer, we can use `model.get_layer(layer).output`, which takes in the name of the layer in question. Let's try getting the `conv5_block16_concat` layer, the raw output of the last convolutional layer.

# %%
spatial_maps =  model.get_layer('conv5_block16_concat').output
print(spatial_maps)
# Out:
# Tensor("conv5_block16_concat/concat:0", shape=(?, ?, ?, 1024), dtype=float32)

# %% [markdown]
# Now, this tensor is just a placeholder, it doesn't contain the actual activations for a particular image. To get this we will use [Keras.backend.function](https://www.tensorflow.org/api_docs/python/tf/keras/backend/function) to return intermediate computations while the model is processing a particular input. This method takes in an input and output placeholders and returns a function. This function will compute the intermediate output (until it reaches the given placeholder) evaluated given the input. For example, if you want the layer that you just retrieved (conv5_block16_concat), you could write the following:

# %%
get_spatial_maps = K.function([model.input], [spatial_maps])
print(get_spatial_maps)
# Out:
# <keras.backend.tensorflow_backend.Function object at 0x7f5a759dfbe0>

# %% [markdown]
# We see that we now have a `Function` object. Now, to get the actual intermediate output evaluated with a particular input, we just plug in an image to this function:

# %%
# get an image
x = load_image_normalize(im_path, mean, std)
print(f"x is of type {type(x)}")
print(f"x is of shape {x.shape}")
# Out:
# x is of type <class 'numpy.ndarray'>
# x is of shape (1, 320, 320, 3)

# %%
# get the spatial maps layer activations (a list of numpy arrays)
spatial_maps_x_l = get_spatial_maps([x])

print(f"spatial_maps_x_l is of type {type(spatial_maps_x_l)}")
print(f"spatial_maps_x_l is has length {len(spatial_maps_x_l)}")
# Out:
# spatial_maps_x_l is of type <class 'list'>
# spatial_maps_x_l is has length 1

# %%
# get the 0th item in the list
spatial_maps_x = spatial_maps_x_l[0]
print(f"spatial_maps_x is of type {type(spatial_maps_x)}")
print(f"spatial_maps_x is of shape {spatial_maps_x.shape}")
# Out:
# spatial_maps_x is of type <class 'numpy.ndarray'>
# spatial_maps_x is of shape (1, 10, 10, 1024)

# %% [markdown]
# Notice that the shape is (1, 10, 10, 1024).  The 0th dimension of size 1 is the batch dimension.  Remove the batch dimension for later calculations by taking the 0th index of spatial_maps_x.

# %%
# Get rid of the batch dimension
spatial_maps_x = spatial_maps_x[0] # equivalent to spatial_maps_x[0,:]
print(f"spatial_maps_x without the batch dimension has shape {spatial_maps_x.shape}")
print("Output some of the content:")
print(spatial_maps_x[0])
# Out:
# spatial_maps_x without the batch dimension has shape (10, 10, 1024)
# Output some of the content:
# [[-0.4399745   0.2263584  -0.63628733 ...  0.1336517  -0.06759723
#    0.1660409 ]
#  [-0.75836414 -0.23234567 -0.90017724 ...  0.2310399  -0.1040216
#    0.28225145]
#  [-0.44548848 -0.04926439 -0.5946444  ...  0.3021959  -0.12835704
#    0.34395525]
#  ...
#  [-0.2951109  -0.34796402 -1.1210403  ...  0.18419634 -0.08923858
#    0.25529334]
#  [-0.3414489  -0.25880516 -0.68925005 ...  0.23115028 -0.11939565
#    0.32885185]
#  [-0.20965514  0.5218969  -0.2501826  ...  0.09946665 -0.05484745
#    0.19365825]]

# %% [markdown]
# We now have the activations for that particular image, and we can use it for interpretation. The function that is returned by calling `K.function([model.input], [spatial_maps])` (saved here in the variable `get_spatial_maps`) is sometimes referred to as a "hook", letting you peek into the intermediate computations in the model.

# %% [markdown]
# <a name="1-1-2"></a>
# #### 1.1.2 Getting Gradients

# %% [markdown]
# The other major step in computing GradCAMs is getting gradients with respect to the output for a particular class. Luckily, Keras makes getting gradients simple. We can use the [Keras.backend.gradients](https://www.tensorflow.org/api_docs/python/tf/keras/backend/gradients) function. The first parameter is the value you are taking the gradient of, and the second is the parameter you are taking that gradient with respect to. We illustrate below:

# %%
# get the output of the model
output_with_batch_dim = model.output
print(f"Model output includes batch dimension, has shape {output_with_batch_dim.shape}")
# Out:
# Model output includes batch dimension, has shape (?, 14)

# %% [markdown]
# To get the output without the batch dimension, you can take the 0th index of the tensor. Note that because the batch dimension is 'None', you could actually enter any integer index, but let's just use 0.

# %%
# Get the output without the batch dimension
output_all_categories = output_with_batch_dim[0]
print(f"The output for all 14 categories of disease has shape {output_all_categories.shape}")
# Out:
# The output for all 14 categories of disease has shape (14,)

# %% [markdown]
# The output has 14 categories, one for each disease category, indexed from 0 to 13. Cardiomegaly is the disease category at index 0.

# %%
# Get the first category's output (Cardiomegaly) at index 0
y_category_0 = output_all_categories[0]
print(f"The Cardiomegaly output is at index 0, and has shape {y_category_0.shape}")
# Out:
# The Cardiomegaly output is at index 0, and has shape ()

# %%
# Get gradient of y_category_0 with respect to spatial_maps

gradient_l = K.gradients(y_category_0, spatial_maps)
print(f"gradient_l is of type {type(gradient_l)} and has length {len(gradient_l)}")

# gradient_l is a list of size 1.  Get the gradient at index 0
gradient = gradient_l[0]
print(gradient)
# Out:
# gradient_l is of type <class 'list'> and has length 1
# Tensor("gradients/AddN:0", shape=(?, ?, ?, 1024), dtype=float32)

# %% [markdown]
# Again, this is just a placeholder. Just like for intermediate layers, we can use `K.function` to compute the value of the gradient for a particular input.
#
# The K.function() takes in
# - a list of inputs: in this case, one input, 'model.input'
# - a list of tensors: in this case, one output tensor 'gradient'
#
# It returns a function that calculates the activations of the list of tensors.
# - This returned function returns a list of the activations, one for each tensor that was passed into K.function().

# %%
# Create the function that gets the gradient
get_gradient = K.function([model.input], [gradient])
type(get_gradient)
# Out:
# keras.backend.tensorflow_backend.Function

# %%
# get an input x-ray image
x = load_image_normalize(im_path, mean, std)
print(f"X-ray image has shape {x.shape}")
# Out:
# X-ray image has shape (1, 320, 320, 3)

# %% [markdown]
# The `get_gradient` function takes in a list of inputs, and returns a list of the gradients, one for each image.

# %%
# use the get_gradient function to get the gradient (pass in the input image inside a list)
grad_x_l = get_gradient([x])
print(f"grad_x_l is of type {type(grad_x_l)} and length {len(grad_x_l)}")

# get the gradient at index 0 of the list.
grad_x_with_batch_dim = grad_x_l[0]
print(f"grad_x_with_batch_dim is type {type(grad_x_with_batch_dim)} and shape {grad_x_with_batch_dim.shape}")

# To remove the batch dimension, take the value at index 0 of the batch dimension
grad_x = grad_x_with_batch_dim[0]
print(f"grad_x is type {type(grad_x)} and shape {grad_x.shape}")

print("Gradient grad_x (show some of its content:")
print(grad_x[0])
# Out:
# grad_x_l is of type <class 'list'> and length 1
# grad_x_with_batch_dim is type <class 'numpy.ndarray'> and shape (1, 10, 10, 1024)
# grad_x is type <class 'numpy.ndarray'> and shape (10, 10, 1024)
# Gradient grad_x (show some of its content:
# [[-1.1127542e-09  2.2419271e-09  2.6272465e-07 ...  7.3359908e-05
#   -4.9100974e-05  5.1160583e-05]
#  [-1.1127542e-09  2.2419271e-09  2.6272465e-07 ...  7.3359908e-05
#   -4.9100974e-05  5.1160583e-05]
#  [-1.1127542e-09  2.2419271e-09  2.6272465e-07 ...  7.3359908e-05
#   -4.9100974e-05  5.1160583e-05]
#  ...
#  [-1.1127542e-09  2.2419271e-09  2.6272465e-07 ...  7.3359908e-05
#   -4.9100974e-05  5.1160583e-05]
#  [-1.1127542e-09  2.2419271e-09  2.6272465e-07 ...  7.3359908e-05
#   -4.9100974e-05  5.1160583e-05]
#  [-1.1127542e-09  2.2419271e-09  2.6272465e-07 ...  7.3359908e-05
#   -4.9100974e-05  5.1160583e-05]]

# %% [markdown]
# Just like we had a hook into the penultimate layer, we now have a hook into the gradient! This allows us to easily compute pretty much anything relevant to our model output.

# %% [markdown]
# We can also combine the two to have one function call which gives us both the gradient and the last layer (this might come in handy when implementing GradCAM in the next section).

# %%
# Use K.function to generate a single function
# Notice that a list of two tensors, is passed in as the second argument of K.function()
get_spatial_maps_and_gradient = K.function([model.input], [spatial_maps, gradient])
print(type(get_spatial_maps_and_gradient))
# Out:
# <class 'keras.backend.tensorflow_backend.Function'>

# %%
# The returned function returns a list of the evaluated tensors
tensor_eval_l = get_spatial_maps_and_gradient([x])
print(f"tensor_eval_l is type {type(tensor_eval_l)} and length {len(tensor_eval_l)}")
# Out:
# tensor_eval_l is type <class 'list'> and length 2

# %%
# store the two numpy arrays from index 0 and 1 into their own variables
spatial_maps_x_with_batch_dim, grad_x_with_batch_dim = tensor_eval_l
print(f"spatial_maps_x_with_batch_dim has shape {spatial_maps_x_with_batch_dim.shape}")
print(f"grad_x_with_batch_dim has shape {grad_x_with_batch_dim.shape}")
# Out:
# spatial_maps_x_with_batch_dim has shape (1, 10, 10, 1024)
# grad_x_with_batch_dim has shape (1, 10, 10, 1024)

# %%
# Note: you could also do this directly from the function call:
spatial_maps_x_with_batch_dim, grad_x_with_batch_dim = get_spatial_maps_and_gradient([x])
print(f"spatial_maps_x_with_batch_dim has shape {spatial_maps_x_with_batch_dim.shape}")
print(f"grad_x_with_batch_dim has shape {grad_x_with_batch_dim.shape}")
# Out:
# spatial_maps_x_with_batch_dim has shape (1, 10, 10, 1024)
# grad_x_with_batch_dim has shape (1, 10, 10, 1024)

# %%
# Remove the batch dimension by taking the 0th index at the batch dimension
spatial_maps_x = spatial_maps_x_with_batch_dim[0]
grad_x = grad_x_with_batch_dim[0]
print(f"spatial_maps_x shape {spatial_maps_x.shape}")
print(f"grad_x shape {grad_x.shape}")

print("\nSpatial maps (print some content):")
print(spatial_maps_x[0])
print("\nGradient (print some content:")
print(grad_x[0])
# Out:
# spatial_maps_x shape (10, 10, 1024)
# grad_x shape (10, 10, 1024)
#
# Spatial maps (print some content):
# [[-0.4399745   0.2263584  -0.63628733 ...  0.1336517  -0.06759723
#    0.1660409 ]
#  [-0.75836414 -0.23234567 -0.90017724 ...  0.2310399  -0.1040216
#    0.28225145]
#  [-0.44548848 -0.04926439 -0.5946444  ...  0.3021959  -0.12835704
#    0.34395525]
#  ...
#  [-0.2951109  -0.34796402 -1.1210403  ...  0.18419634 -0.08923858
#    0.25529334]
#  [-0.3414489  -0.25880516 -0.68925005 ...  0.23115028 -0.11939565
#    0.32885185]
#  [-0.20965514  0.5218969  -0.2501826  ...  0.09946665 -0.05484745
#    0.19365825]]
#
# Gradient (print some content:
# [[-1.1127542e-09  2.2419271e-09  2.6272465e-07 ...  7.3359908e-05
#   -4.9100974e-05  5.1160583e-05]
#  [-1.1127542e-09  2.2419271e-09  2.6272465e-07 ...  7.3359908e-05
#   -4.9100974e-05  5.1160583e-05]
#  [-1.1127542e-09  2.2419271e-09  2.6272465e-07 ...  7.3359908e-05
#   -4.9100974e-05  5.1160583e-05]
#  ...
#  [-1.1127542e-09  2.2419271e-09  2.6272465e-07 ...  7.3359908e-05
#   -4.9100974e-05  5.1160583e-05]
#  [-1.1127542e-09  2.2419271e-09  2.6272465e-07 ...  7.3359908e-05
#   -4.9100974e-05  5.1160583e-05]
#  [-1.1127542e-09  2.2419271e-09  2.6272465e-07 ...  7.3359908e-05
#   -4.9100974e-05  5.1160583e-05]]

# %% [markdown]
# <a name="1-1-3"></a>
# #### 1.1.3 Implementing GradCAM

# %% [markdown]
# <a name='ex-01'></a>
# ### Exercise 1
#
# In the next cell, fill in the `grad_cam` method to produce GradCAM visualizations for an input model and image. This is fairly complicated, so it might help to break it down into these steps:
#
# 1. Hook into model output and last layer activations.
# 2. Get gradients of last layer activations with respect to output.
# 3. Compute value of last layer and gradients for input image.
# 4. Compute weights from gradients by global average pooling.
# 5. Compute the dot product between the last layer and weights to get the score for each pixel.
# 6. Resize, take ReLU, and return cam.

# %% [markdown]
# <details>
#     <summary>
#     <font size="3" color="darkgreen"><b>Hints</b></font>
# </summary>
#
#  The following hints follow the order of the sections described above.
#  1. Remember that the output shape of our model will be [1, class_amount].
#      1. The input in this case will always have batch_size = 1
#  2. See [K.gradients](https://www.tensorflow.org/api_docs/python/tf/keras/backend/gradients)
#  3. Follow the procedure we used in the previous two sections.
#  4. Check the axis; make sure weights have shape (C)!
#  5. See [np.dot](https://docs.scipy.org/doc/numpy/reference/generated/numpy.dot.html)
#      </details>

# %% [markdown]
# To test, you will compare your output on an image to the output from a correct implementation of GradCAM. You will receive full credit if the pixel-wise mean squared error is less than 0.05.

# %%
# UNQ_C1 (UNIQUE CELL IDENTIFIER, DO NOT EDIT)
def grad_cam(input_model, image, category_index, layer_name):
    """
    GradCAM method for visualizing input saliency.
    
    Args:
        input_model (Keras.model): model to compute cam for
        image (tensor): input to model, shape (1, H, W, 3)
        cls (int): class to compute cam with respect to
        layer_name (str): relevant layer in model
        H (int): input height
        W (int): input width
    Return:
        cam ()
    """
    cam = None
    
    ### START CODE HERE (REPLACE INSTANCES OF 'None' with your code) ###

    # 1. Get placeholders for class output and last layer
    # Get the model's output
    output_with_batch_dim = input_model.output
    
    # Remove the batch dimension
    output_all_categories = output_with_batch_dim[0]
    
    # Retrieve only the disease category at the given category index
    y_c = output_all_categories[category_index]
    
    # Get the input model's layer specified by layer_name, and retrive the layer's output tensor
    spatial_map_layer = input_model.get_layer(layer_name).output

    # 2. Get gradients of last layer with respect to output

    # get the gradients of y_c with respect to the spatial map layer (it's a list of length 1)
    grads_l = K.gradients(y_c, spatial_map_layer)
    
    # Get the gradient at index 0 of the list
    grads = grads_l[0]
        
    # 3. Get hook for the selected layer and its gradient, based on given model's input
    # Hint: Use the variables produced by the previous two lines of code
    spatial_map_and_gradient_function = K.function([input_model.input], [spatial_map_layer, grads])
    
    # Put in the image to calculate the values of the spatial_maps (selected layer) and values of the gradients
    spatial_map_all_dims, grads_val_all_dims = spatial_map_and_gradient_function([image])

    # Reshape activations and gradient to remove the batch dimension
    # Shape goes from (B, H, W, C) to (H, W, C)
    # B: Batch. H: Height. W: Width. C: Channel    
    # Reshape spatial map output to remove the batch dimension
    spatial_map_val = spatial_map_all_dims[0]
    
    # Reshape gradients to remove the batch dimension
    grads_val = grads_val_all_dims[0]
    
    # 4. Compute weights using global average pooling on gradient 
    # grads_val has shape (Height, Width, Channels) (H,W,C)
    # Take the mean across the height and also width, for each channel
    # Make sure weights have shape (C)
    weights = np.mean(grads_val,axis=(0,1))
    
    # 5. Compute dot product of spatial map values with the weights
    cam = np.dot(spatial_map_val,weights)

    ### END CODE HERE ###
    
    # We'll take care of the postprocessing.
    H, W = image.shape[1], image.shape[2]
    cam = np.maximum(cam, 0) # ReLU so we only get positive importance
    cam = cv2.resize(cam, (W, H), cv2.INTER_NEAREST)
    cam = cam / cam.max()

    return cam

# %% [markdown]
# Below we generate the CAM for the image and compute the error (pixel-wise mean squared difference) from the expected values according to our reference.

# %%
im = load_image_normalize(im_path, mean, std)
cam = grad_cam(model, im, 5, 'conv5_block16_concat') # Mass is class 5

# Loads reference CAM to compare our implementation with.
reference = np.load("reference_cam.npy")
error = np.mean((cam-reference)**2)

print(f"Error from reference: {error:.4f}, should be less than 0.05")
# Out:
# Error from reference: 0.0307, should be less than 0.05

# %% [markdown]
# Run the next cell to visualize the CAM and the original image.

# %%
plt.imshow(load_image(im_path, df, preprocess=False), cmap='gray')
plt.title("Original")
plt.axis('off')

plt.show()

plt.imshow(load_image(im_path, df, preprocess=False), cmap='gray')
plt.imshow(cam, cmap='magma', alpha=0.5)
plt.title("GradCAM")
plt.axis('off')
plt.show()

# %% [markdown]
# We can see that it focuses on the large (white) empty area on the right lung. Indeed this is a clear case of Mass.

# %% [markdown]
# <a name="1-1-4"></a>
# #### 1.1.4 Using GradCAM to Visualize Multiple Labels

# %% [markdown]
# <a name='ex-02'></a>
# ### Exercise 2
#
# We can use GradCAMs for multiple labels on the same image. Let's do it for the labels with best AUC for our model, Cardiomegaly, Mass, and Edema.

# %%
# UNQ_C2 (UNIQUE CELL IDENTIFIER, DO NOT EDIT)
def compute_gradcam(model, img, mean, std, data_dir, df, 
                    labels, selected_labels, layer_name='conv5_block16_concat'):
    """
    Compute GradCAM for many specified labels for an image. 
    This method will use the `grad_cam` function.
    
    Args:
        model (Keras.model): Model to compute GradCAM for
        img (string): Image name we want to compute GradCAM for.
        mean (float): Mean to normalize to image.
        std (float): Standard deviation to normalize the image.
        data_dir (str): Path of the directory to load the images from.
        df(pd.Dataframe): Dataframe with the image features.
        labels ([str]): All output labels for the model.
        selected_labels ([str]): All output labels we want to compute the GradCAM for.
        layer_name: Intermediate layer from the model we want to compute the GradCAM for.
    """
    img_path = data_dir + img
    preprocessed_input = load_image_normalize(img_path, mean, std)
    predictions = model.predict(preprocessed_input)
    print("Ground Truth: ", ", ".join(np.take(labels, np.nonzero(df[df["Image"] == img][labels].values[0]))[0]))

    plt.figure(figsize=(15, 10))
    plt.subplot(151)
    plt.title("Original")
    plt.axis('off')
    plt.imshow(load_image(img_path, df, preprocess=False), cmap='gray')
    
    j = 1
    
    ### START CODE HERE (REPLACE INSTANCES OF 'None' with your code) ###    
    # Loop through all labels
    for i in range(len(labels)): # complete this line
        # Compute CAM and show plots for each selected label.
        
        # Check if the label is one of the selected labels
        if labels[i] in selected_labels: # complete this line
            
            # Use the grad_cam function to calculate gradcam
            gradcam = grad_cam(model, preprocessed_input, i, layer_name)
            
            ### END CODE HERE ###
            
            print("Generating gradcam for class %s (p=%2.2f)" % (labels[i], round(predictions[0][i], 3)))
            plt.subplot(151 + j)
            plt.title(labels[i] + ": " + str(round(predictions[0][i], 3)))
            plt.axis('off')
            plt.imshow(load_image(img_path, df, preprocess=False), cmap='gray')
            plt.imshow(gradcam, cmap='magma', alpha=min(0.5, predictions[0][i]))
            j +=1

# %% [markdown]
# Run the following cells to print the ground truth diagnosis for a given case and show the original x-ray as well as GradCAMs for Cardiomegaly, Mass, and Edema.

# %%
df = pd.read_csv("nih_new/train-small.csv")

image_filename = '00016650_000.png'
labels_to_show = ['Cardiomegaly', 'Mass', 'Edema']
compute_gradcam(model, image_filename, mean, std, IMAGE_DIR, df, labels, labels_to_show)
# Out:
# Ground Truth:  Cardiomegaly
# Generating gradcam for class Cardiomegaly (p=0.96)
# Generating gradcam for class Mass (p=0.30)
# Generating gradcam for class Edema (p=0.15)

# %% [markdown]
# The model correctly predicts absence of mass or edema. The probability for mass is higher, and we can see that it may be influenced by the shapes in the middle of the chest cavity, as well as around the shoulder. We'll run it for two more images.

# %%
image_filename = '00005410_000.png'
compute_gradcam(model, image_filename, mean, std, IMAGE_DIR, df, labels, labels_to_show)
# Out:
# Ground Truth:  Mass
# Generating gradcam for class Cardiomegaly (p=0.02)
# Generating gradcam for class Mass (p=0.99)
# Generating gradcam for class Edema (p=0.40)

# %% [markdown]
# In the example above, the model correctly focuses on the mass near the center of the chest cavity.

# %%
image_name = '00004090_002.png'
compute_gradcam(model, image_name, mean, std, IMAGE_DIR, df, labels, labels_to_show)
# Out:
# Ground Truth:  Edema
# Generating gradcam for class Cardiomegaly (p=0.69)
# Generating gradcam for class Mass (p=0.23)
# Generating gradcam for class Edema (p=1.00)

# %% [markdown]
# Here the model correctly picks up the signs of edema near the bottom of the chest cavity. We can also notice that Cardiomegaly has a high score for this image, though the ground truth doesn't include it. This visualization might be helpful for error analysis; for example, we can notice that the model is indeed looking at the expected area to make the prediction.

# %% [markdown]
# This concludes the section on GradCAMs. We hope you've gained an appreciation for the importance of interpretation when it comes to deep learning models in medicine. Interpretation tools like this one can be helpful for discovery of markers, error analysis, and even in deployment.

# %% [markdown]
# <a name="2"></a>
# ## 2 Feature Importance in Machine Learning

# %% [markdown]
# When developing predictive models and risk measures, it's often helpful to know which features are making the most difference. This is easy to determine in simpler models such as linear models and decision trees. However as we move to more complex models to achieve high performance, we usually sacrifice some interpretability. In this assignment we'll try to regain some of that interpretability using Shapley values, a technique which has gained popularity in recent years, but which is based on classic results in cooperative game theory.
#
# We'll revisit our random forest model from course 2 module 2 and try to analyze it more closely using Shapley values. Run the next cell to load in the data and model from that assignment and recalculate the test set c-index.

# %%
rf = pickle.load(open('nhanes_rf.sav', 'rb')) # Loading the model
test_df = pd.read_csv('nhanest_test.csv')
test_df = test_df.drop(test_df.columns[0], axis=1)
X_test = test_df.drop('y', axis=1)
y_test = test_df.loc[:, 'y']
cindex_test = cindex(y_test, rf.predict_proba(X_test)[:, 1])

print("Model C-index on test: {}".format(cindex_test))
# Out:
# Model C-index on test: 0.7776169781865744

# %% [markdown]
# Run the next cell to print out the riskiest individuals according to our model.

# %%
X_test_risky = X_test.copy(deep=True)
X_test_risky.loc[:, 'risk'] = rf.predict_proba(X_test)[:, 1] # Predicting our risk.
X_test_risky = X_test_risky.sort_values(by='risk', ascending=False) # Sorting by risk value.
X_test_risky.head()
# Out:
#        Age  Diastolic BP  Poverty index  Race  Red blood cells  \
# 572   70.0          80.0          312.0   1.0             54.8
# 190   69.0         100.0          316.0   1.0             77.7
# 1300  73.0          80.0          999.0   1.0             52.6
# 634   66.0         100.0           69.0   2.0             42.9
# 1221  74.0          80.0           67.0   1.0             40.3
#
#       Sedimentation rate  Serum Albumin  Serum Cholesterol  Serum Iron  \
# 572                  7.0            4.4              222.0        52.0
# 190                 26.0            4.2              197.0        65.0
# 1300                35.0            3.9              258.0        61.0
# 634                 47.0            3.8              233.0       170.0
# 1221                24.0            3.7              139.0        28.0
#
#       Serum Magnesium  Serum Protein  Sex  Systolic BP   TIBC    TS  \
# 572              1.57            7.2  1.0        180.0  417.0  12.5
# 190              1.49            7.5  1.0        165.0  298.0  21.8
# 1300             1.66            6.8  1.0        150.0  314.0  19.4
# 634              1.42            8.6  1.0        180.0  411.0  41.4
# 1221             1.91            6.4  2.0        140.0  495.0   5.7
#
#       White blood cells        BMI  Pulse pressure  risk
# 572                 7.5  45.770473           100.0  0.77
# 190                 8.8  22.129018            65.0  0.69
# 1300                9.4  26.466850            70.0  0.69
# 634                 7.2  22.129498            80.0  0.68
# 1221                4.1  22.066389            60.0  0.68

# %% [markdown]
# <a name="2-1"></a>
# ### 2.1 Permuation Method for Feature Importance
#
# First we'll try to determine feature importance using the permutation method. In the permutation method, the importance of feature $i$ would be the regular performance of the model minus the performance with the values for feature $i$ permuted in the dataset. This way we can assess how well a model without that feature would do without having to train a new model for each feature.

# %% [markdown]
# <a name="2-1-1"></a>
# #### 2.1.1 Implementing Permutation

# %% [markdown]
# <a name='ex-03'></a>
# ### Exercise 3
#
# Complete the implementation of the function below, which given a feature name returns a dataset with those feature values randomly permuted.

# %% [markdown]
# <details>
#     <summary>
#     <font size="3" color="darkgreen"><b>Hints</b></font>
# </summary>
#     <ul>
#         <li>
#             See <a href=https://numpy.org/devdocs/reference/random/generated/numpy.random.permutation.html> np.random.permutation</a>
#         </li>
#     </ul>
# </details>

# %%
# UNQ_C3 (UNIQUE CELL IDENTIFIER, DO NOT EDIT)
def permute_feature(df, feature):
    """
    Given dataset, returns version with the values of
    the given feature randomly permuted. 

    Args:
        df (dataframe): The dataset, shape (num subjects, num features)
        feature (string): Name of feature to permute
    Returns:
        permuted_df (dataframe): Exactly the same as df except the values
                                of the given feature are randomly permuted.
    """
    permuted_df = df.copy(deep=True) # Make copy so we don't change original df

    ### START CODE HERE (REPLACE INSTANCES OF 'None' with your code) ###

    # Permute the values of the column 'feature'
    permuted_features = np.random.permutation(permuted_df[feature])
    
    # Set the column 'feature' to its permuted values.
    permuted_df[feature] = permuted_features
    
    ### END CODE HERE ###

    return permuted_df

# %%
print("Test Case")

example_df = pd.DataFrame({'col1': [0, 1, 2], 'col2':['A', 'B', 'C']})
print("Original dataframe:")
print(example_df)
print("\n")

print("col1 permuted:")
print(permute_feature(example_df, 'col1'))

print("\n")
print("Compute average values over 1000 runs to get expected values:")
col1_values = np.zeros((3, 1000))
np.random.seed(0) # Adding a constant seed so we can always expect the same values and evaluate correctly. 
for i in range(1000):
    col1_values[:, i] = permute_feature(example_df, 'col1')['col1'].values

print("Average of col1: {}, expected value: [0.976, 1.03, 0.994]".format(np.mean(col1_values, axis=1)))
# Out:
# Test Case
# Original dataframe:
#    col1 col2
# 0     0    A
# 1     1    B
# 2     2    C
#
#
# col1 permuted:
#    col1 col2
# 0     1    A
# 1     2    B
# 2     0    C
#
#
# Compute average values over 1000 runs to get expected values:
# Average of col1: [0.976 1.03  0.994], expected value: [0.976, 1.03, 0.994]

# %% [markdown]
# <a name="2-1-2"></a>
# #### 2.1.2 Implementing Importance

# %% [markdown]
# <a name='ex-04'></a>
# ### Exercise 4
#
# Now we will use the function we just created to compute feature importances (according to the permutation method) in the function below.

# %% [markdown]
# <details>
#     <summary>
#     <font size="3" color="darkgreen"><b>Hints</b></font>
# </summary>
# \begin{align}
# I_x  = \left\lvert perf - perf_x  \right\rvert
# \end{align}
#
# where $I_x$ is the importance of feature $x$ and
# \begin{align}
# perf_x  = \frac{1}{n}\cdot \sum_{i=1}^{n} perf_i^{sx}
# \end{align}
#
# where $perf_i^{sx}$ is the performance with the feature $x$ shuffled in the $i$th permutation.
# </details>

# %%
# UNQ_C4 (UNIQUE CELL IDENTIFIER, DO NOT EDIT)
def permutation_importance(X, y, model, metric, num_samples = 100):
    """
    Compute permutation importance for each feature.

    Args:
        X (dataframe): Dataframe for test data, shape (num subject, num features)
        y (np.array): Labels for each row of X, shape (num subjects,)
        model (object): Model to compute importances for, guaranteed to have
                        a 'predict_proba' method to compute probabilistic 
                        predictions given input
        metric (function): Metric to be used for feature importance. Takes in ground
                           truth and predictions as the only two arguments
        num_samples (int): Number of samples to average over when computing change in
                           performance for each feature
    Returns:
        importances (dataframe): Dataframe containing feature importance for each
                                 column of df with shape (1, num_features)
    """

    importances = pd.DataFrame(index = ['importance'], columns = X.columns)
    
    # Get baseline performance (note, you'll use this metric function again later)
    baseline_performance = metric(y, model.predict_proba(X)[:, 1])

    ### START CODE HERE (REPLACE INSTANCES OF 'None' with your code) ###

    # Iterate over features (the columns in the importances dataframe)
    for feature in X.columns: # complete this line
        
        # Compute 'num_sample' performances by permutating that feature
        
        # You'll see how the model performs when the feature is permuted
        # You'll do this num_samples number of times, and save the performance each time
        # To store the feature performance,
        # create a numpy array of size num_samples, initialized to all zeros
        feature_performance_arr = np.zeros(num_samples)
        
        # Loop through each sample
        for i in range(num_samples): # complete this line
            
            # permute the column of dataframe X
            perm_X = permute_feature(X, feature)
            
            # calculate the performance with the permuted data
            # Use the same metric function that was used earlier
            feature_performance_arr[i] = metric(y, model.predict_proba(perm_X)[:, 1])
    
    
        # Compute importance: absolute difference between 
        # the baseline performance and the average across the feature performance
        importances[feature]['importance'] = baseline_performance - np.mean(feature_performance_arr)
        
    ### END CODE HERE ###

    return importances

# %% [markdown]
# **Test Case**

# %%
print("Test Case")
print("\n")
print("We check our answers on a Logistic Regression on a dataset")
print("where y is given by a sigmoid applied to the important feature.") 
print("The unimportant feature is random noise.")
print("\n")
example_df = pd.DataFrame({'important': np.random.normal(size=(1000)), 'unimportant':np.random.normal(size=(1000))})
example_y = np.round(1 / (1 + np.exp(-example_df.important)))
example_model = sklearn.linear_model.LogisticRegression(fit_intercept=False).fit(example_df, example_y)

example_importances = permutation_importance(example_df, example_y, example_model, cindex, num_samples=100)
print("Computed importances:")
print(example_importances)
print("\n")
print("Expected importances (approximate values):")
print(pd.DataFrame({"important": 0.50, "unimportant": 0.00}, index=['importance']))
print("If you round the actual values, they will be similar to the expected values")
# Out:
# Test Case
#
#
# We check our answers on a Logistic Regression on a dataset
# where y is given by a sigmoid applied to the important feature.
# The unimportant feature is random noise.
#
#
# Computed importances:
#            important  unimportant
# importance  0.496674 -2.89012e-05
#
#
# Expected importances (approximate values):
#             important  unimportant
# importance        0.5          0.0
# If you round the actual values, they will be similar to the expected values

# %% [markdown]
# <a name="2-1-3"></a>
# #### 2.1.3 Computing our Feature Importance

# %% [markdown]
# Next, we compute importances on our dataset. Since we are computing the permutation importance for all the features, it might take a few minutes to run.

# %%
importances = permutation_importance(X_test, y_test, rf, cindex, num_samples=100)
importances
# Out:
#                  Age Diastolic BP Poverty index         Race Red blood cells  \
# importance  0.147772    0.0113034     0.0111148  0.000449158     0.000805694
#
#            Sedimentation rate Serum Albumin Serum Cholesterol   Serum Iron  \
# importance           0.006285    0.00527172      -0.000848118  0.000203789
#
#            Serum Magnesium Serum Protein        Sex Systolic BP        TIBC  \
# importance      0.00274019   -0.00154867  0.0272337  0.00618949  0.00225922
#
#                      TS White blood cells         BMI Pulse pressure
# importance  0.000425288        0.00256128  0.00304884     0.00379624

# %% [markdown]
# Let's plot these in a bar chart for easier comparison.

# %%
importances.T.plot.bar()
plt.ylabel("Importance")
l = plt.legend()
l.remove()
plt.show()

# %% [markdown]
# You should see age as by far the best prediction of near term mortality, as one might expect. Next is sex, followed by diastolic blood pressure. Interestingly, the poverty index also has a large impact, despite the fact that it is not directly related to an individual's health. This alludes to the importance of social determinants of health in our model.

# %% [markdown]
# <a name="2-2"></a>
# ### 2.2 Shapley Values for Random Forests

# %% [markdown]
# We'll contrast the permutation method with a more recent technique known as Shapley values (actually, Shapley values date back to the mid 20th century, but have only been applied to machine learning very recently).

# %% [markdown]
# <a name="2-2-1"></a>
# #### 2.2.1 Visualizing Feature Importance on Specific Individuals

# %% [markdown]
# We can use Shapley values to try and understand the model output on specific individuals. In general Shapley values take exponential time to compute, but luckily there are faster approximations for forests in particular that run in polynomial time. Run the next cell to display a 'force plot' showing how each feature influences the output for the first person in our dataset. If you want more information about 'force plots' and other decision plots, please take a look at [this notebook](https://github.com/slundberg/shap/blob/master/notebooks/plots/decision_plot.ipynb) by the `shap` library creators.

# %%
explainer = shap.TreeExplainer(rf)
i = 0 # Picking an individual
shap_value = explainer.shap_values(X_test.loc[X_test_risky.index[i], :])[1]
shap.force_plot(explainer.expected_value[1], shap_value, feature_names=X_test.columns, matplotlib=True)
# Out:
# Setting feature_perturbation = "tree_path_dependent" because no background data was given.

# %% [markdown]
# For this individual, their age, pulse pressure, and sex were the biggest contributors to their high risk prediction. Note how shapley values give us greater granularity in our interpretations.
#
# Feel free to change the `i` value above to explore the feature influences for different individuals.

# %% [markdown]
# <a name="2-2-2"></a>
# #### 2.2.2 Visualizing Feature Importance on Aggregate

# %% [markdown]
# Just like with the permutation method, we might also want to understand model output in aggregate. Shapley values allow us to do this as well. Run the next cell to initialize the shapley values for each example in the test set (this may also take a few minutes).

# %%
shap_values = shap.TreeExplainer(rf).shap_values(X_test)[1]
# Out:
# Setting feature_perturbation = "tree_path_dependent" because no background data was given.

# %% [markdown]
# You can ignore the `setting feature_perturbation` message.

# %% [markdown]
# Run the next cell to see a summary plot of the shapley values for each feature on each of the test examples. The colors indicate the value of the feature. The features are listed in terms of decreasing absolute average shapley value over all the individuals in the dataset.

# %%
shap.summary_plot(shap_values, X_test)

# %% [markdown]
# In the above plot, you might be able to notice a high concentration of points on specific SHAP value ranges. This means that a high proportion of our test set lies on those ranges.
#
# As with the permutation method, age, sex, poverty index, and diastolic BP seem to be the most important features. Being older has a negative impact on mortality, and being a woman (sex=2.0) has a positive effect.

# %% [markdown]
# <a name="2-2-3"></a>
# #### 2.2.3 Visualizing Interactions between Features

# %% [markdown]
# The `shap` library also lets you visualize interactions between features using dependence plots. These plot the Shapley value for a given feature for each data point, and color the points in using the value for another feature. This lets us begin to explain the variation in shapley value for a single value of the main feature.

# %% [markdown]
# Run the next cell to see the interaction between Age and Sex.

# %%
shap.dependence_plot('Age', shap_values, X_test, interaction_index = 'Sex')

# %% [markdown]
# We see that while Age > 50 is generally bad (positive Shapley value), being a woman (red points) generally reduces the impact of age. This makes sense since we know that women generally live longer than men.

# %% [markdown]
# Run the next cell to see the interaction between Poverty index and Age

# %%
shap.dependence_plot('Poverty index', shap_values, X_test, interaction_index='Age')

# %% [markdown]
# We see that the impact of poverty index drops off quickly, and for higher income individuals age begins to explain much of variation in the impact of poverty index. We encourage you to try some other pairs and see what other interesting relationships you can find!

# %% [markdown]
# Congratulations! You've completed the final assignment of course 3, well done!

# %%
# !tar cvfz allfiles.tar.gz *
# Out:
# C3M3_Assignment.ipynb
# __MACOSX/
# __MACOSX/._densenet.hdf5
# __MACOSX/nih_new/
# __MACOSX/nih_new/._valid-toy.csv
# __MACOSX/nih_new/images-small/
# __MACOSX/nih_new/images-small/._00000772_001.png
# __MACOSX/nih_new/images-small/._00001663_001.png
# __MACOSX/nih_new/images-small/._00008171_000.png
# __MACOSX/nih_new/images-small/._00026469_006.png
# __MACOSX/nih_new/images-small/._00006585_009.png
# __MACOSX/nih_new/images-small/._00023128_001.png
# __MACOSX/nih_new/images-small/._00006551_000.png
# __MACOSX/nih_new/images-small/._00009701_000.png
# __MACOSX/nih_new/images-small/._00015214_013.png
# __MACOSX/nih_new/images-small/._00030652_001.png
# __MACOSX/nih_new/images-small/._00014015_006.png
# __MACOSX/nih_new/images-small/._00021463_001.png
# __MACOSX/nih_new/images-small/._00020290_004.png
# __MACOSX/nih_new/images-small/._00025703_000.png
# __MACOSX/nih_new/images-small/._00003481_001.png
# __MACOSX/nih_new/images-small/._00005309_000.png
# __MACOSX/nih_new/images-small/._00016036_001.png
# __MACOSX/nih_new/images-small/._00021509_000.png
# __MACOSX/nih_new/images-small/._00008727_009.png
# __MACOSX/nih_new/images-small/._00018013_004.png
# __MACOSX/nih_new/images-small/._00030323_015.png
# __MACOSX/nih_new/images-small/._00006434_000.png
# __MACOSX/nih_new/images-small/._00017126_000.png
# __MACOSX/nih_new/images-small/._00006272_000.png
# __MACOSX/nih_new/images-small/._00026925_027.png
# __MACOSX/nih_new/images-small/._00021128_003.png
# __MACOSX/nih_new/images-small/._00012043_016.png
# __MACOSX/nih_new/images-small/._00022093_001.png
# __MACOSX/nih_new/images-small/._00002491_001.png
# __MACOSX/nih_new/images-small/._00010390_004.png
# __MACOSX/nih_new/images-small/._00026889_000.png
# __MACOSX/nih_new/images-small/._00020915_000.png
# __MACOSX/nih_new/images-small/._00027299_004.png
# __MACOSX/nih_new/images-small/._00013209_020.png
# __MACOSX/nih_new/images-small/._00020517_002.png
# __MACOSX/nih_new/images-small/._00023696_007.png
# __MACOSX/nih_new/images-small/._00017702_000.png
# __MACOSX/nih_new/images-small/._00020076_002.png
# __MACOSX/nih_new/images-small/._00001373_030.png
# __MACOSX/nih_new/images-small/._00018512_000.png
# __MACOSX/nih_new/images-small/._00011544_020.png
# __MACOSX/nih_new/images-small/._00026050_004.png
# __MACOSX/nih_new/images-small/._00009365_028.png
# __MACOSX/nih_new/images-small/._00013931_000.png
# __MACOSX/nih_new/images-small/._00010582_001.png
# __MACOSX/nih_new/images-small/._00011156_003.png
# __MACOSX/nih_new/images-small/._00016604_000.png
# __MACOSX/nih_new/images-small/._00027592_017.png
# __MACOSX/nih_new/images-small/._00008975_004.png
# __MACOSX/nih_new/images-small/._00006799_002.png
# __MACOSX/nih_new/images-small/._00018494_007.png
# __MACOSX/nih_new/images-small/._00027213_002.png
# __MACOSX/nih_new/images-small/._00011355_002.png
# __MACOSX/nih_new/images-small/._00026997_000.png
# __MACOSX/nih_new/images-small/._00010428_002.png
# __MACOSX/nih_new/images-small/._00027888_000.png
# __MACOSX/nih_new/images-small/._00010535_012.png
# __MACOSX/nih_new/images-small/._00028304_000.png
# __MACOSX/nih_new/images-small/._00000032_039.png
# __MACOSX/nih_new/images-small/._00027685_005.png
# __MACOSX/nih_new/images-small/._00010294_010.png
# __MACOSX/nih_new/images-small/._00012363_002.png
# __MACOSX/nih_new/images-small/._00000248_021.png
# __MACOSX/nih_new/images-small/._00007735_038.png
# __MACOSX/nih_new/images-small/._00017135_000.png
# __MACOSX/nih_new/images-small/._00012722_003.png
# __MACOSX/nih_new/images-small/._00005416_001.png
# __MACOSX/nih_new/images-small/._00023116_004.png
# __MACOSX/nih_new/images-small/._00014677_008.png
# __MACOSX/nih_new/images-small/._00002743_001.png
# __MACOSX/nih_new/images-small/._00021616_001.png
# __MACOSX/nih_new/images-small/._00021338_000.png
# __MACOSX/nih_new/images-small/._00025613_000.png
# __MACOSX/nih_new/images-small/._00024560_000.png
# __MACOSX/nih_new/images-small/._00002704_004.png
# __MACOSX/nih_new/images-small/._00011852_000.png
# __MACOSX/nih_new/images-small/._00025081_010.png
# __MACOSX/nih_new/images-small/._00020213_036.png
# __MACOSX/nih_new/images-small/._00021653_000.png
# __MACOSX/nih_new/images-small/._00013685_028.png
# __MACOSX/nih_new/images-small/._00028844_034.png
# __MACOSX/nih_new/images-small/._00004523_003.png
# __MACOSX/nih_new/images-small/._00021201_092.png
# __MACOSX/nih_new/images-small/._00014798_004.png
# __MACOSX/nih_new/images-small/._00021293_000.png
# __MACOSX/nih_new/images-small/._00016109_000.png
# __MACOSX/nih_new/images-small/._00003523_031.png
# __MACOSX/nih_new/images-small/._00012707_000.png
# __MACOSX/nih_new/images-small/._00011770_001.png
# __MACOSX/nih_new/images-small/._00003552_002.png
# __MACOSX/nih_new/images-small/._00023154_002.png
# __MACOSX/nih_new/images-small/._00003868_008.png
# __MACOSX/nih_new/images-small/._00002661_002.png
# __MACOSX/nih_new/images-small/._00017645_002.png
# __MACOSX/nih_new/images-small/._00023128_009.png
# __MACOSX/nih_new/images-small/._00014296_003.png
# __MACOSX/nih_new/images-small/._00017807_002.png
# __MACOSX/nih_new/images-small/._00005983_000.png
# __MACOSX/nih_new/images-small/._00002796_001.png
# __MACOSX/nih_new/images-small/._00027282_004.png
# __MACOSX/nih_new/images-small/._00006634_006.png
# __MACOSX/nih_new/images-small/._00001986_001.png
# __MACOSX/nih_new/images-small/._00001430_001.png
# __MACOSX/nih_new/images-small/._00006436_006.png
# __MACOSX/nih_new/images-small/._00010967_011.png
# __MACOSX/nih_new/images-small/._00009507_004.png
# __MACOSX/nih_new/images-small/._00019708_000.png
# __MACOSX/nih_new/images-small/._00030024_000.png
# __MACOSX/nih_new/images-small/._00005094_016.png
# __MACOSX/nih_new/images-small/._00029165_002.png
# __MACOSX/nih_new/images-small/._00013229_008.png
# __MACOSX/nih_new/images-small/._00007468_000.png
# __MACOSX/nih_new/images-small/._00006021_000.png
# __MACOSX/nih_new/images-small/._00012094_045.png
# __MACOSX/nih_new/images-small/._00020240_001.png
# __MACOSX/nih_new/images-small/._00026494_000.png
# __MACOSX/nih_new/images-small/._00003863_005.png
# __MACOSX/nih_new/images-small/._00001610_001.png
# __MACOSX/nih_new/images-small/._00008515_006.png
# __MACOSX/nih_new/images-small/._00016657_000.png
# __MACOSX/nih_new/images-small/._00007828_000.png
# __MACOSX/nih_new/images-small/._00010758_004.png
# __MACOSX/nih_new/images-small/._00001437_019.png
# __MACOSX/nih_new/images-small/._00010294_027.png
# __MACOSX/nih_new/images-small/._00013625_044.png
# __MACOSX/nih_new/images-small/._00009562_003.png
# __MACOSX/nih_new/images-small/._00005646_004.png
# __MACOSX/nih_new/images-small/._00015003_000.png
# __MACOSX/nih_new/images-small/._00023296_003.png
# __MACOSX/nih_new/images-small/._00008508_004.png
# __MACOSX/nih_new/images-small/._00013572_007.png
# __MACOSX/nih_new/images-small/._00015756_001.png
# __MACOSX/nih_new/images-small/._00018661_003.png
# __MACOSX/nih_new/images-small/._00014981_002.png
# __MACOSX/nih_new/images-small/._00023283_016.png
# __MACOSX/nih_new/images-small/._00022526_008.png
# __MACOSX/nih_new/images-small/._00008348_002.png
# __MACOSX/nih_new/images-small/._00012884_002.png
# __MACOSX/nih_new/images-small/._00018627_001.png
# __MACOSX/nih_new/images-small/._00006906_022.png
# __MACOSX/nih_new/images-small/._00022870_015.png
# __MACOSX/nih_new/images-small/._00016480_006.png
# __MACOSX/nih_new/images-small/._00020458_015.png
# __MACOSX/nih_new/images-small/._00000798_010.png
# __MACOSX/nih_new/images-small/._00027464_011.png
# __MACOSX/nih_new/images-small/._00008368_000.png
# __MACOSX/nih_new/images-small/._00010808_008.png
# __MACOSX/nih_new/images-small/._00029570_002.png
# __MACOSX/nih_new/images-small/._00008760_004.png
# __MACOSX/nih_new/images-small/._00028285_000.png
# __MACOSX/nih_new/images-small/._00007873_000.png
# __MACOSX/nih_new/images-small/._00025650_007.png
# __MACOSX/nih_new/images-small/._00007670_041.png
# __MACOSX/nih_new/images-small/._00013950_007.png
# __MACOSX/nih_new/images-small/._00019733_002.png
# __MACOSX/nih_new/images-small/._00021772_006.png
# __MACOSX/nih_new/images-small/._00027260_017.png
# __MACOSX/nih_new/images-small/._00008010_000.png
# __MACOSX/nih_new/images-small/._00001701_000.png
# __MACOSX/nih_new/images-small/._00006944_002.png
# __MACOSX/nih_new/images-small/._00013249_033.png
# __MACOSX/nih_new/images-small/._00022785_001.png
# __MACOSX/nih_new/images-small/._00018724_003.png
# __MACOSX/nih_new/images-small/._00019059_001.png
# __MACOSX/nih_new/images-small/._00027912_004.png
# __MACOSX/nih_new/images-small/._00028606_003.png
# __MACOSX/nih_new/images-small/._00013088_001.png
# __MACOSX/nih_new/images-small/._00019594_027.png
# __MACOSX/nih_new/images-small/._00008885_008.png
# __MACOSX/nih_new/images-small/._00009340_005.png
# __MACOSX/nih_new/images-small/._00010932_006.png
# __MACOSX/nih_new/images-small/._00011584_002.png
# __MACOSX/nih_new/images-small/._00013049_004.png
# __MACOSX/nih_new/images-small/._00026232_006.png
# __MACOSX/nih_new/images-small/._00028416_000.png
# __MACOSX/nih_new/images-small/._00015530_133.png
# __MACOSX/nih_new/images-small/._00030733_005.png
# __MACOSX/nih_new/images-small/._00025383_000.png
# __MACOSX/nih_new/images-small/._00006868_009.png
# __MACOSX/nih_new/images-small/._00010007_139.png
# __MACOSX/nih_new/images-small/._00002474_004.png
# __MACOSX/nih_new/images-small/._00024175_002.png
# __MACOSX/nih_new/images-small/._00022717_002.png
# __MACOSX/nih_new/images-small/._00020738_001.png
# __MACOSX/nih_new/images-small/._00021463_005.png
# __MACOSX/nih_new/images-small/._00002478_000.png
# __MACOSX/nih_new/images-small/._00010497_000.png
# __MACOSX/nih_new/images-small/._00001749_000.png
# __MACOSX/nih_new/images-small/._00011702_082.png
# __MACOSX/nih_new/images-small/._00028873_018.png
# __MACOSX/nih_new/images-small/._00018056_001.png
# __MACOSX/nih_new/images-small/._00002592_003.png
# __MACOSX/nih_new/images-small/._00017423_004.png
# __MACOSX/nih_new/images-small/._00017508_000.png
# __MACOSX/nih_new/images-small/._00025527_000.png
# __MACOSX/nih_new/images-small/._00024474_000.png
# __MACOSX/nih_new/images-small/._00004872_000.png
# __MACOSX/nih_new/images-small/._00011567_001.png
# __MACOSX/nih_new/images-small/._00019406_001.png
# __MACOSX/nih_new/images-small/._00012176_004.png
# __MACOSX/nih_new/images-small/._00000678_000.png
# __MACOSX/nih_new/images-small/._00016092_003.png
# __MACOSX/nih_new/images-small/._00000832_008.png
# __MACOSX/nih_new/images-small/._00029244_000.png
# __MACOSX/nih_new/images-small/._00016094_001.png
# __MACOSX/nih_new/images-small/._00020277_003.png
# __MACOSX/nih_new/images-small/._00015360_006.png
# __MACOSX/nih_new/images-small/._00029863_018.png
# __MACOSX/nih_new/images-small/._00000865_011.png
# __MACOSX/nih_new/images-small/._00009245_001.png
# __MACOSX/nih_new/images-small/._00009326_001.png
# __MACOSX/nih_new/images-small/._00009727_039.png
# __MACOSX/nih_new/images-small/._00014911_005.png
# __MACOSX/nih_new/images-small/._00019521_003.png
# __MACOSX/nih_new/images-small/._00001872_012.png
# __MACOSX/nih_new/images-small/._00004581_003.png
# __MACOSX/nih_new/images-small/._00000588_000.png
# __MACOSX/nih_new/images-small/._00006713_013.png
# __MACOSX/nih_new/images-small/._00009911_001.png
# __MACOSX/nih_new/images-small/._00009552_000.png
# __MACOSX/nih_new/images-small/._00016521_006.png
# __MACOSX/nih_new/images-small/._00001794_000.png
# __MACOSX/nih_new/images-small/._00003576_000.png
# __MACOSX/nih_new/images-small/._00017373_000.png
# __MACOSX/nih_new/images-small/._00026480_001.png
# __MACOSX/nih_new/images-small/._00012765_000.png
# __MACOSX/nih_new/images-small/._00029711_001.png
# __MACOSX/nih_new/images-small/._00016568_038.png
# __MACOSX/nih_new/images-small/._00011553_006.png
# __MACOSX/nih_new/images-small/._00011355_042.png
# __MACOSX/nih_new/images-small/._00009798_013.png
# __MACOSX/nih_new/images-small/._00001659_000.png
# __MACOSX/nih_new/images-small/._00027631_002.png
# __MACOSX/nih_new/images-small/._00003675_000.png
# __MACOSX/nih_new/images-small/._00003752_004.png
# __MACOSX/nih_new/images-small/._00018958_006.png
# __MACOSX/nih_new/images-small/._00016860_000.png
# __MACOSX/nih_new/images-small/._00016410_018.png
# __MACOSX/nih_new/images-small/._00029091_000.png
# __MACOSX/nih_new/images-small/._00007390_002.png
# __MACOSX/nih_new/images-small/._00011493_003.png
# __MACOSX/nih_new/images-small/._00023276_001.png
# __MACOSX/nih_new/images-small/._00013278_000.png
# __MACOSX/nih_new/images-small/._00003670_005.png
# __MACOSX/nih_new/images-small/._00020846_001.png
# __MACOSX/nih_new/images-small/._00017470_002.png
# __MACOSX/nih_new/images-small/._00008328_000.png
# __MACOSX/nih_new/images-small/._00023158_002.png
# __MACOSX/nih_new/images-small/._00021179_001.png
# __MACOSX/nih_new/images-small/._00014320_047.png
# __MACOSX/nih_new/images-small/._00003534_024.png
# __MACOSX/nih_new/images-small/._00019333_002.png
# __MACOSX/nih_new/images-small/._00011391_024.png
# __MACOSX/nih_new/images-small/._00014107_000.png
# __MACOSX/nih_new/images-small/._00002721_001.png
# __MACOSX/nih_new/images-small/._00029188_001.png
# __MACOSX/nih_new/images-small/._00018187_031.png
# __MACOSX/nih_new/images-small/._00005832_038.png
# __MACOSX/nih_new/images-small/._00028844_012.png
# __MACOSX/nih_new/images-small/._00026793_002.png
# __MACOSX/nih_new/images-small/._00030023_005.png
# __MACOSX/nih_new/images-small/._00001831_000.png
# __MACOSX/nih_new/images-small/._00000940_000.png
# __MACOSX/nih_new/images-small/._00015628_007.png
# __MACOSX/nih_new/images-small/._00011251_021.png
# __MACOSX/nih_new/images-small/._00011713_000.png
# __MACOSX/nih_new/images-small/._00007687_001.png
# __MACOSX/nih_new/images-small/._00003489_005.png
# __MACOSX/nih_new/images-small/._00006043_000.png
# __MACOSX/nih_new/images-small/._00019861_004.png
# __MACOSX/nih_new/images-small/._00009826_004.png
# __MACOSX/nih_new/images-small/._00009185_006.png
# __MACOSX/nih_new/images-small/._00005231_002.png
# __MACOSX/nih_new/images-small/._00025628_006.png
# __MACOSX/nih_new/images-small/._00022125_001.png
# __MACOSX/nih_new/images-small/._00021114_004.png
# __MACOSX/nih_new/images-small/._00019469_000.png
# __MACOSX/nih_new/images-small/._00029861_003.png
# __MACOSX/nih_new/images-small/._00019847_000.png
# __MACOSX/nih_new/images-small/._00016258_007.png
# __MACOSX/nih_new/images-small/._00012505_000.png
# __MACOSX/nih_new/images-small/._00001855_037.png
# __MACOSX/nih_new/images-small/._00026500_000.png
# __MACOSX/nih_new/images-small/._00022260_001.png
# __MACOSX/nih_new/images-small/._00025754_015.png
# __MACOSX/nih_new/images-small/._00030082_000.png
# __MACOSX/nih_new/images-small/._00028591_004.png
# __MACOSX/nih_new/images-small/._00001301_035.png
# __MACOSX/nih_new/images-small/._00012413_011.png
# __MACOSX/nih_new/images-small/._00010524_001.png
# __MACOSX/nih_new/images-small/._00012777_005.png
# __MACOSX/nih_new/images-small/._00022458_008.png
# __MACOSX/nih_new/images-small/._00019528_004.png
# __MACOSX/nih_new/images-small/._00018860_015.png
# __MACOSX/nih_new/images-small/._00009953_012.png
# __MACOSX/nih_new/images-small/._00026497_001.png
# __MACOSX/nih_new/images-small/._00010433_011.png
# __MACOSX/nih_new/images-small/._00002898_002.png
# __MACOSX/nih_new/images-small/._00005089_043.png
# __MACOSX/nih_new/images-small/._00014197_007.png
# __MACOSX/nih_new/images-small/._00019962_002.png
# __MACOSX/nih_new/images-small/._00007510_000.png
# __MACOSX/nih_new/images-small/._00009446_006.png
# __MACOSX/nih_new/images-small/._00006926_015.png
# __MACOSX/nih_new/images-small/._00012993_014.png
# __MACOSX/nih_new/images-small/._00008291_018.png
# __MACOSX/nih_new/images-small/._00025664_015.png
# __MACOSX/nih_new/images-small/._00012019_000.png
# __MACOSX/nih_new/images-small/._00026489_000.png
# __MACOSX/nih_new/images-small/._00010272_001.png
# __MACOSX/nih_new/images-small/._00019635_005.png
# __MACOSX/nih_new/images-small/._00007894_001.png
# __MACOSX/nih_new/images-small/._00000552_001.png
# __MACOSX/nih_new/images-small/._00007141_000.png
# __MACOSX/nih_new/images-small/._00005986_010.png
# __MACOSX/nih_new/images-small/._00019899_018.png
# __MACOSX/nih_new/images-small/._00018546_005.png
# __MACOSX/nih_new/images-small/._00027618_005.png
# __MACOSX/nih_new/images-small/._00000315_004.png
# __MACOSX/nih_new/images-small/._00025746_014.png
# __MACOSX/nih_new/images-small/._00008981_003.png
# __MACOSX/nih_new/images-small/._00008741_009.png
# __MACOSX/nih_new/images-small/._00004270_000.png
# __MACOSX/nih_new/images-small/._00002846_009.png
# __MACOSX/nih_new/images-small/._00017753_024.png
# __MACOSX/nih_new/images-small/._00009912_008.png
# __MACOSX/nih_new/images-small/._00011420_023.png
# __MACOSX/nih_new/images-small/._00000634_000.png
# __MACOSX/nih_new/images-small/._00016882_004.png
# __MACOSX/nih_new/images-small/._00014134_000.png
# __MACOSX/nih_new/images-small/._00028766_000.png
# __MACOSX/nih_new/images-small/._00010651_000.png
# __MACOSX/nih_new/images-small/._00010334_002.png
# __MACOSX/nih_new/images-small/._00030415_000.png
# __MACOSX/nih_new/images-small/._00007958_000.png
# __MACOSX/nih_new/images-small/._00015498_002.png
# __MACOSX/nih_new/images-small/._00010888_004.png
# __MACOSX/nih_new/images-small/._00027594_002.png
# __MACOSX/nih_new/images-small/._00027833_006.png
# __MACOSX/nih_new/images-small/._00013603_000.png
# __MACOSX/nih_new/images-small/._00012233_002.png
# __MACOSX/nih_new/images-small/._00027202_000.png
# __MACOSX/nih_new/images-small/._00008841_044.png
# __MACOSX/nih_new/images-small/._00020405_017.png
# __MACOSX/nih_new/images-small/._00000658_000.png
# __MACOSX/nih_new/images-small/._00004360_015.png
# __MACOSX/nih_new/images-small/._00028018_000.png
# __MACOSX/nih_new/images-small/._00019108_000.png
# __MACOSX/nih_new/images-small/._00002000_001.png
# __MACOSX/nih_new/images-small/._00003841_003.png
# __MACOSX/nih_new/images-small/._00013999_004.png
# __MACOSX/nih_new/images-small/._00008081_011.png
# __MACOSX/nih_new/images-small/._00015507_001.png
# __MACOSX/nih_new/images-small/._00018810_001.png
# __MACOSX/nih_new/images-small/._00012556_000.png
# __MACOSX/nih_new/images-small/._00013111_093.png
# __MACOSX/nih_new/images-small/._00016714_000.png
# __MACOSX/nih_new/images-small/._00026232_040.png
# __MACOSX/nih_new/images-small/._00015224_005.png
# __MACOSX/nih_new/images-small/._00004096_000.png
# __MACOSX/nih_new/images-small/._00010092_043.png
# __MACOSX/nih_new/images-small/._00022159_000.png
# __MACOSX/nih_new/images-small/._00027240_004.png
# __MACOSX/nih_new/images-small/._00000020_001.png
# __MACOSX/nih_new/images-small/._00013564_000.png
# __MACOSX/nih_new/images-small/._00012835_000.png
# __MACOSX/nih_new/images-small/._00005904_001.png
# __MACOSX/nih_new/images-small/._00017997_002.png
# __MACOSX/nih_new/images-small/._00016009_030.png
# __MACOSX/nih_new/images-small/._00010475_020.png
# __MACOSX/nih_new/images-small/._00016318_000.png
# __MACOSX/nih_new/images-small/._00013424_005.png
# __MACOSX/nih_new/images-small/._00001806_004.png
# __MACOSX/nih_new/images-small/._00000359_002.png
# __MACOSX/nih_new/images-small/._00001648_000.png
# __MACOSX/nih_new/images-small/._00013111_039.png
# __MACOSX/nih_new/images-small/._00007894_007.png
# __MACOSX/nih_new/images-small/._00003148_003.png
# __MACOSX/nih_new/images-small/._00022526_011.png
# __MACOSX/nih_new/images-small/._00023065_003.png
# __MACOSX/nih_new/images-small/._00026414_002.png
# __MACOSX/nih_new/images-small/._00026136_001.png
# __MACOSX/nih_new/images-small/._00012736_000.png
# __MACOSX/nih_new/images-small/._00029323_000.png
# __MACOSX/nih_new/images-small/._00014706_010.png
# __MACOSX/nih_new/images-small/._00015007_006.png
# __MACOSX/nih_new/images-small/._00004344_013.png
# __MACOSX/nih_new/images-small/._00019405_000.png
# __MACOSX/nih_new/images-small/._00017503_003.png
# __MACOSX/nih_new/images-small/._00008033_005.png
# __MACOSX/nih_new/images-small/._00025252_030.png
# __MACOSX/nih_new/images-small/._00030393_001.png
# __MACOSX/nih_new/images-small/._00006019_003.png
# __MACOSX/nih_new/images-small/._00017061_004.png
# __MACOSX/nih_new/images-small/._00002890_000.png
# __MACOSX/nih_new/images-small/._00010476_001.png
# __MACOSX/nih_new/images-small/._00001395_010.png
# __MACOSX/nih_new/images-small/._00016019_002.png
# __MACOSX/nih_new/images-small/._00017262_001.png
# __MACOSX/nih_new/images-small/._00000111_000.png
# __MACOSX/nih_new/images-small/._00018145_000.png
# __MACOSX/nih_new/images-small/._00013209_013.png
# __MACOSX/nih_new/images-small/._00012515_014.png
# __MACOSX/nih_new/images-small/._00012520_009.png
# __MACOSX/nih_new/images-small/._00010387_000.png
# __MACOSX/nih_new/images-small/._00020188_000.png
# __MACOSX/nih_new/images-small/._00014146_003.png
# __MACOSX/nih_new/images-small/._00020326_105.png
# __MACOSX/nih_new/images-small/._00006192_010.png
# __MACOSX/nih_new/images-small/._00008701_003.png
# __MACOSX/nih_new/images-small/._00013969_007.png
# __MACOSX/nih_new/images-small/._00023372_002.png
# __MACOSX/nih_new/images-small/._00011155_006.png
# __MACOSX/nih_new/images-small/._00007034_023.png
# __MACOSX/nih_new/images-small/._00012144_025.png
# __MACOSX/nih_new/images-small/._00002350_018.png
# __MACOSX/nih_new/images-small/._00025695_017.png
# __MACOSX/nih_new/images-small/._00004149_001.png
# __MACOSX/nih_new/images-small/._00013534_003.png
# __MACOSX/nih_new/images-small/._00016122_007.png
# __MACOSX/nih_new/images-small/._00012326_005.png
# __MACOSX/nih_new/images-small/._00012249_001.png
# __MACOSX/nih_new/images-small/._00010535_014.png
# __MACOSX/nih_new/images-small/._00027235_000.png
# __MACOSX/nih_new/images-small/._00007034_005.png
# __MACOSX/nih_new/images-small/._00008468_018.png
# __MACOSX/nih_new/images-small/._00002702_008.png
# __MACOSX/nih_new/images-small/._00010531_072.png
# __MACOSX/nih_new/images-small/._00015081_013.png
# __MACOSX/nih_new/images-small/._00011850_004.png
# __MACOSX/nih_new/images-small/._00004893_029.png
# __MACOSX/nih_new/images-small/._00001972_000.png
# __MACOSX/nih_new/images-small/._00012903_004.png
# __MACOSX/nih_new/images-small/._00001891_000.png
# __MACOSX/nih_new/images-small/._00016719_029.png
# __MACOSX/nih_new/images-small/._00013716_001.png
# __MACOSX/nih_new/images-small/._00014710_015.png
# __MACOSX/nih_new/images-small/._00006229_000.png
# __MACOSX/nih_new/images-small/._00000284_005.png
# __MACOSX/nih_new/images-small/._00021376_000.png
# __MACOSX/nih_new/images-small/._00004725_001.png
# __MACOSX/nih_new/images-small/._00001297_000.png
# __MACOSX/nih_new/images-small/._00020602_009.png
# __MACOSX/nih_new/images-small/._00026505_001.png
# __MACOSX/nih_new/images-small/._00011136_007.png
# __MACOSX/nih_new/images-small/._00018855_000.png
# __MACOSX/nih_new/images-small/._00004497_003.png
# __MACOSX/nih_new/images-small/._00008745_030.png
# __MACOSX/nih_new/images-small/._00006039_009.png
# __MACOSX/nih_new/images-small/._00021982_005.png
# __MACOSX/nih_new/images-small/._00012161_000.png
# __MACOSX/nih_new/images-small/._00011269_008.png
# __MACOSX/nih_new/images-small/._00030340_001.png
# __MACOSX/nih_new/images-small/._00013641_048.png
# __MACOSX/nih_new/images-small/._00008081_019.png
# __MACOSX/nih_new/images-small/._00014022_002.png
# __MACOSX/nih_new/images-small/._00023967_000.png
# __MACOSX/nih_new/images-small/._00027287_001.png
# __MACOSX/nih_new/images-small/._00015647_022.png
# __MACOSX/nih_new/images-small/._00027486_000.png
# __MACOSX/nih_new/images-small/._00004735_008.png
# __MACOSX/nih_new/images-small/._00005746_005.png
# __MACOSX/nih_new/images-small/._00001190_000.png
# __MACOSX/nih_new/images-small/._00005132_000.png
# __MACOSX/nih_new/images-small/._00028871_001.png
# __MACOSX/nih_new/images-small/._00006297_003.png
# __MACOSX/nih_new/images-small/._00018000_002.png
# __MACOSX/nih_new/images-small/._00029808_000.png
# __MACOSX/nih_new/images-small/._00009368_001.png
# __MACOSX/nih_new/images-small/._00006104_000.png
# __MACOSX/nih_new/images-small/._00017549_001.png
# __MACOSX/nih_new/images-small/._00026451_009.png
# __MACOSX/nih_new/images-small/._00011054_000.png
# __MACOSX/nih_new/images-small/._00014758_002.png
# __MACOSX/nih_new/images-small/._00017731_017.png
# __MACOSX/nih_new/images-small/._00000640_001.png
# __MACOSX/nih_new/images-small/._00001836_090.png
# __MACOSX/nih_new/images-small/._00021449_007.png
# __MACOSX/nih_new/images-small/._00022883_013.png
# __MACOSX/nih_new/images-small/._00024597_000.png
# __MACOSX/nih_new/images-small/._00017819_010.png
# __MACOSX/nih_new/images-small/._00026810_046.png
# __MACOSX/nih_new/images-small/._00029682_000.png
# __MACOSX/nih_new/images-small/._00011211_005.png
# __MACOSX/nih_new/images-small/._00027863_001.png
# __MACOSX/nih_new/images-small/._00021489_003.png
# __MACOSX/nih_new/images-small/._00009807_003.png
# __MACOSX/nih_new/images-small/._00017158_032.png
# __MACOSX/nih_new/images-small/._00021818_025.png
# __MACOSX/nih_new/images-small/._00017691_003.png
# __MACOSX/nih_new/images-small/._00013655_007.png
# __MACOSX/nih_new/images-small/._00012276_018.png
# __MACOSX/nih_new/images-small/._00015732_027.png
# __MACOSX/nih_new/images-small/._00026964_000.png
# __MACOSX/nih_new/images-small/._00008068_005.png
# __MACOSX/nih_new/images-small/._00001385_019.png
# __MACOSX/nih_new/images-small/._00026641_008.png
# __MACOSX/nih_new/images-small/._00020819_016.png
# __MACOSX/nih_new/images-small/._00019870_002.png
# __MACOSX/nih_new/images-small/._00026685_000.png
# __MACOSX/nih_new/images-small/._00006851_034.png
# __MACOSX/nih_new/images-small/._00027355_005.png
# __MACOSX/nih_new/images-small/._00025295_004.png
# __MACOSX/nih_new/images-small/._00020052_002.png
# __MACOSX/nih_new/images-small/._00025971_003.png
# __MACOSX/nih_new/images-small/._00003395_007.png
# __MACOSX/nih_new/images-small/._00001107_002.png
# __MACOSX/nih_new/images-small/._00027477_000.png
# __MACOSX/nih_new/images-small/._00004992_012.png
# __MACOSX/nih_new/images-small/._00028876_048.png
# __MACOSX/nih_new/images-small/._00003393_045.png
# __MACOSX/nih_new/images-small/._00024849_000.png
# __MACOSX/nih_new/images-small/._00028996_009.png
# __MACOSX/nih_new/images-small/._00028081_008.png
# __MACOSX/nih_new/images-small/._00011885_013.png
# __MACOSX/nih_new/images-small/._00001143_002.png
# __MACOSX/nih_new/images-small/._00020213_003.png
# __MACOSX/nih_new/images-small/._00016983_000.png
# __MACOSX/nih_new/images-small/._00028682_001.png
# __MACOSX/nih_new/images-small/._00013003_040.png
# __MACOSX/nih_new/images-small/._00012874_032.png
# __MACOSX/nih_new/images-small/._00006031_001.png
# __MACOSX/nih_new/images-small/._00006395_000.png
# __MACOSX/nih_new/images-small/._00004458_002.png
# __MACOSX/nih_new/images-small/._00007185_020.png
# __MACOSX/nih_new/images-small/._00012829_010.png
# __MACOSX/nih_new/images-small/._00022237_007.png
# __MACOSX/nih_new/images-small/._00000583_034.png
# __MACOSX/nih_new/images-small/._00002759_000.png
# __MACOSX/nih_new/images-small/._00001033_000.png
# __MACOSX/nih_new/images-small/._00028811_003.png
# __MACOSX/nih_new/images-small/._00012935_021.png
# __MACOSX/nih_new/images-small/._00012045_038.png
# __MACOSX/nih_new/images-small/._00014358_020.png
# __MACOSX/nih_new/images-small/._00026412_026.png
# __MACOSX/nih_new/images-small/._00012594_002.png
# __MACOSX/nih_new/images-small/._00025580_003.png
# __MACOSX/nih_new/images-small/._00016952_000.png
# __MACOSX/nih_new/images-small/._00019625_000.png
# __MACOSX/nih_new/images-small/._00019899_003.png
# __MACOSX/nih_new/images-small/._00020819_003.png
# __MACOSX/nih_new/images-small/._00019382_000.png
# __MACOSX/nih_new/images-small/._00028550_003.png
# __MACOSX/nih_new/images-small/._00007816_010.png
# __MACOSX/nih_new/images-small/._00026057_003.png
# __MACOSX/nih_new/images-small/._00005962_001.png
# __MACOSX/nih_new/images-small/._00000599_000.png
# __MACOSX/nih_new/images-small/._00015078_011.png
# __MACOSX/nih_new/images-small/._00010877_000.png
# __MACOSX/nih_new/images-small/._00000468_014.png
# __MACOSX/nih_new/images-small/._00009281_003.png
# __MACOSX/nih_new/images-small/._00004824_014.png
# __MACOSX/nih_new/images-small/._00015166_004.png
# __MACOSX/nih_new/images-small/._00025843_001.png
# __MACOSX/nih_new/images-small/._00019409_000.png
# __MACOSX/nih_new/images-small/._00028192_001.png
# __MACOSX/nih_new/images-small/._00016052_009.png
# __MACOSX/nih_new/images-small/._00016813_004.png
# __MACOSX/nih_new/images-small/._00009048_002.png
# __MACOSX/nih_new/images-small/._00004438_004.png
# __MACOSX/nih_new/images-small/._00005723_006.png
# __MACOSX/nih_new/images-small/._00005532_035.png
# __MACOSX/nih_new/images-small/._00003947_000.png
# __MACOSX/nih_new/images-small/._00011632_019.png
# __MACOSX/nih_new/images-small/._00004595_000.png
# __MACOSX/nih_new/images-small/._00027743_000.png
# __MACOSX/nih_new/images-small/._00017236_103.png
# __MACOSX/nih_new/images-small/._00006010_000.png
# __MACOSX/nih_new/images-small/._00002847_002.png
# __MACOSX/nih_new/images-small/._00026168_000.png
# __MACOSX/nih_new/images-small/._00026236_013.png
# __MACOSX/nih_new/images-small/._00001952_006.png
# __MACOSX/nih_new/images-small/._00008147_003.png
# __MACOSX/nih_new/images-small/._00026087_000.png
# __MACOSX/nih_new/images-small/._00004822_007.png
# __MACOSX/nih_new/images-small/._00010936_013.png
# __MACOSX/nih_new/images-small/._00018383_000.png
# __MACOSX/nih_new/images-small/._00021398_000.png
# __MACOSX/nih_new/images-small/._00020908_004.png
# __MACOSX/nih_new/images-small/._00017735_000.png
# __MACOSX/nih_new/images-small/._00012047_009.png
# __MACOSX/nih_new/images-small/._00022764_002.png
# __MACOSX/nih_new/images-small/._00017541_032.png
# __MACOSX/nih_new/images-small/._00016184_021.png
# __MACOSX/nih_new/images-small/._00009553_001.png
# __MACOSX/nih_new/images-small/._00001833_008.png
# __MACOSX/nih_new/images-small/._00029435_000.png
# __MACOSX/nih_new/images-small/._00020469_002.png
# __MACOSX/nih_new/images-small/._00013615_007.png
# __MACOSX/nih_new/images-small/._00029192_000.png
# __MACOSX/nih_new/images-small/._00005639_000.png
# __MACOSX/nih_new/images-small/._00008563_001.png
# __MACOSX/nih_new/images-small/._00018086_000.png
# __MACOSX/nih_new/images-small/._00019850_000.png
# __MACOSX/nih_new/images-small/._00016825_001.png
# __MACOSX/nih_new/images-small/._00020158_016.png
# __MACOSX/nih_new/images-small/._00026825_000.png
# __MACOSX/nih_new/images-small/._00004833_014.png
# __MACOSX/nih_new/images-small/._00008270_015.png
# __MACOSX/nih_new/images-small/._00007790_000.png
# __MACOSX/nih_new/images-small/._00008911_013.png
# __MACOSX/nih_new/images-small/._00022622_009.png
# __MACOSX/nih_new/images-small/._00022982_000.png
# __MACOSX/nih_new/images-small/._00014128_007.png
# __MACOSX/nih_new/images-small/._00025787_028.png
# __MACOSX/nih_new/images-small/._00028606_001.png
# __MACOSX/nih_new/images-small/._00007717_001.png
# __MACOSX/nih_new/images-small/._00023079_002.png
# __MACOSX/nih_new/images-small/._00008284_001.png
# __MACOSX/nih_new/images-small/._00016341_008.png
# __MACOSX/nih_new/images-small/._00026322_000.png
# __MACOSX/nih_new/images-small/._00016007_001.png
# __MACOSX/nih_new/images-small/._00011517_000.png
# __MACOSX/nih_new/images-small/._00008220_003.png
# __MACOSX/nih_new/images-small/._00007016_001.png
# __MACOSX/nih_new/images-small/._00022993_006.png
# __MACOSX/nih_new/images-small/._00014520_021.png
# __MACOSX/nih_new/images-small/._00026555_008.png
# __MACOSX/nih_new/images-small/._00010346_001.png
# __MACOSX/nih_new/images-small/._00019984_000.png
# __MACOSX/nih_new/images-small/._00003689_005.png
# __MACOSX/nih_new/images-small/._00004144_002.png
# __MACOSX/nih_new/images-small/._00000116_034.png
# __MACOSX/nih_new/images-small/._00010427_001.png
# __MACOSX/nih_new/images-small/._00022362_000.png
# __MACOSX/nih_new/images-small/._00019230_000.png
# __MACOSX/nih_new/images-small/._00007133_001.png
# __MACOSX/nih_new/images-small/._00022803_000.png
# __MACOSX/nih_new/images-small/._00026599_000.png
# __MACOSX/nih_new/images-small/._00009033_000.png
# __MACOSX/nih_new/images-small/._00001194_000.png
# __MACOSX/nih_new/images-small/._00003523_011.png
# __MACOSX/nih_new/images-small/._00005502_012.png
# __MACOSX/nih_new/images-small/._00006360_000.png
# __MACOSX/nih_new/images-small/._00010120_029.png
# __MACOSX/nih_new/images-small/._00027547_006.png
# __MACOSX/nih_new/images-small/._00011535_000.png
# __MACOSX/nih_new/images-small/._00012264_000.png
# __MACOSX/nih_new/images-small/._00002660_001.png
# __MACOSX/nih_new/images-small/._00001006_017.png
# __MACOSX/nih_new/images-small/._00009368_005.png
# __MACOSX/nih_new/images-small/._00024009_000.png
# __MACOSX/nih_new/images-small/._00012345_000.png
# __MACOSX/nih_new/images-small/._00008387_014.png
# __MACOSX/nih_new/images-small/._00000443_004.png
# __MACOSX/nih_new/images-small/._00001253_004.png
# __MACOSX/nih_new/images-small/._00007943_008.png
# __MACOSX/nih_new/images-small/._00014603_001.png
# __MACOSX/nih_new/images-small/._00030162_003.png
# __MACOSX/nih_new/images-small/._00011256_000.png
# __MACOSX/nih_new/images-small/._00008403_000.png
# __MACOSX/nih_new/images-small/._00012021_081.png
# __MACOSX/nih_new/images-small/._00005759_014.png
# __MACOSX/nih_new/images-small/._00019014_000.png
# __MACOSX/nih_new/images-small/._00027975_001.png
# __MACOSX/nih_new/images-small/._00003028_002.png
# __MACOSX/nih_new/images-small/._00007106_001.png
# __MACOSX/nih_new/images-small/._00030156_000.png
# __MACOSX/nih_new/images-small/._00005241_003.png
# __MACOSX/nih_new/images-small/._00008841_064.png
# __MACOSX/nih_new/images-small/._00012615_000.png
# __MACOSX/nih_new/images-small/._00018103_011.png
# __MACOSX/nih_new/images-small/._00017178_007.png
# __MACOSX/nih_new/images-small/._00013670_149.png
# __MACOSX/nih_new/images-small/._00007670_029.png
# __MACOSX/nih_new/images-small/._00021711_012.png
# __MACOSX/nih_new/images-small/._00016034_001.png
# __MACOSX/nih_new/images-small/._00013523_001.png
# __MACOSX/nih_new/images-small/._00019939_000.png
# __MACOSX/nih_new/images-small/._00005089_018.png
# __MACOSX/nih_new/images-small/._00015977_002.png
# __MACOSX/nih_new/images-small/._00018615_037.png
# __MACOSX/nih_new/images-small/._00010050_009.png
# __MACOSX/nih_new/images-small/._00000375_000.png
# __MACOSX/nih_new/images-small/._00026222_010.png
# __MACOSX/nih_new/images-small/._00011426_001.png
# __MACOSX/nih_new/images-small/._00002192_001.png
# __MACOSX/nih_new/images-small/._00004090_002.png
# __MACOSX/nih_new/images-small/._00026825_008.png
# __MACOSX/nih_new/images-small/._00027357_007.png
# __MACOSX/nih_new/images-small/._00019578_001.png
# __MACOSX/nih_new/images-small/._00015495_007.png
# __MACOSX/nih_new/images-small/._00006234_000.png
# __MACOSX/nih_new/images-small/._00011425_002.png
# __MACOSX/nih_new/images-small/._00028846_003.png
# __MACOSX/nih_new/images-small/._00019774_003.png
# __MACOSX/nih_new/images-small/._00015893_005.png
# __MACOSX/nih_new/images-small/._00014334_000.png
# __MACOSX/nih_new/images-small/._00014368_009.png
# __MACOSX/nih_new/images-small/._00009953_023.png
# __MACOSX/nih_new/images-small/._00010352_022.png
# __MACOSX/nih_new/images-small/._00011894_008.png
# __MACOSX/nih_new/images-small/._00017504_059.png
# __MACOSX/nih_new/images-small/._00003122_007.png
# __MACOSX/nih_new/images-small/._00008767_003.png
# __MACOSX/nih_new/images-small/._00012622_011.png
# __MACOSX/nih_new/images-small/._00004523_013.png
# __MACOSX/nih_new/images-small/._00016064_010.png
# __MACOSX/nih_new/images-small/._00010352_061.png
# __MACOSX/nih_new/images-small/._00029142_000.png
# __MACOSX/nih_new/images-small/._00009368_017.png
# __MACOSX/nih_new/images-small/._00003867_019.png
# __MACOSX/nih_new/images-small/._00001382_004.png
# __MACOSX/nih_new/images-small/._00000773_001.png
# __MACOSX/nih_new/images-small/._00002393_001.png
# __MACOSX/nih_new/images-small/._00019967_011.png
# __MACOSX/nih_new/images-small/._00016142_013.png
# __MACOSX/nih_new/images-small/._00007523_001.png
# __MACOSX/nih_new/images-small/._00002156_004.png
# __MACOSX/nih_new/images-small/._00017243_001.png
# __MACOSX/nih_new/images-small/._00014082_012.png
# __MACOSX/nih_new/images-small/._00014849_008.png
# __MACOSX/nih_new/images-small/._00000457_002.png
# __MACOSX/nih_new/images-small/._00014332_005.png
# __MACOSX/nih_new/images-small/._00005183_001.png
# __MACOSX/nih_new/images-small/._00000538_002.png
# __MACOSX/nih_new/images-small/._00025128_000.png
# __MACOSX/nih_new/images-small/._00022899_031.png
# __MACOSX/nih_new/images-small/._00018711_000.png
# __MACOSX/nih_new/images-small/._00023508_000.png
# __MACOSX/nih_new/images-small/._00002772_000.png
# __MACOSX/nih_new/images-small/._00030393_000.png
# __MACOSX/nih_new/images-small/._00012573_000.png
# __MACOSX/nih_new/images-small/._00000918_000.png
# __MACOSX/nih_new/images-small/._00028070_001.png
# __MACOSX/nih_new/images-small/._00005400_009.png
# __MACOSX/nih_new/images-small/._00010557_000.png
# __MACOSX/nih_new/images-small/._00016019_001.png
# __MACOSX/nih_new/images-small/._00001805_004.png
# __MACOSX/nih_new/images-small/._00000914_004.png
# __MACOSX/nih_new/images-small/._00021168_000.png
# __MACOSX/nih_new/images-small/._00030158_001.png
# __MACOSX/nih_new/images-small/._00001526_004.png
# __MACOSX/nih_new/images-small/._00001911_015.png
# __MACOSX/nih_new/images-small/._00004006_035.png
# __MACOSX/nih_new/images-small/._00020318_004.png
# __MACOSX/nih_new/images-small/._00011049_003.png
# __MACOSX/nih_new/images-small/._00011366_001.png
# __MACOSX/nih_new/images-small/._00001248_003.png
# __MACOSX/nih_new/images-small/._00001718_010.png
# __MACOSX/nih_new/images-small/._00008316_000.png
# __MACOSX/nih_new/images-small/._00027900_000.png
# __MACOSX/nih_new/images-small/._00011484_000.png
# __MACOSX/nih_new/images-small/._00029201_004.png
# __MACOSX/nih_new/images-small/._00016650_000.png
# __MACOSX/nih_new/images-small/._00020213_028.png
# __MACOSX/nih_new/images-small/._00018432_000.png
# __MACOSX/nih_new/images-small/._00029950_009.png
# __MACOSX/nih_new/images-small/._00016971_028.png
# __MACOSX/nih_new/images-small/._00003573_000.png
# __MACOSX/nih_new/images-small/._00023372_001.png
# __MACOSX/nih_new/images-small/._00012761_001.png
# __MACOSX/nih_new/images-small/._00028140_003.png
# __MACOSX/nih_new/images-small/._00026004_006.png
# __MACOSX/nih_new/images-small/._00011380_014.png
# __MACOSX/nih_new/images-small/._00019981_006.png
# __MACOSX/nih_new/images-small/._00008142_003.png
# __MACOSX/nih_new/images-small/._00007533_000.png
# __MACOSX/nih_new/images-small/._00004898_005.png
# __MACOSX/nih_new/images-small/._00000549_000.png
# __MACOSX/nih_new/images-small/._00026208_000.png
# __MACOSX/nih_new/images-small/._00021154_005.png
# __MACOSX/nih_new/images-small/._00007442_010.png
# __MACOSX/nih_new/images-small/._00020213_091.png
# __MACOSX/nih_new/images-small/._00028062_000.png
# __MACOSX/nih_new/images-small/._00008297_008.png
# __MACOSX/nih_new/images-small/._00012049_002.png
# __MACOSX/nih_new/images-small/._00012622_023.png
# __MACOSX/nih_new/images-small/._00004544_001.png
# __MACOSX/nih_new/images-small/._00026125_002.png
# __MACOSX/nih_new/images-small/._00010827_000.png
# __MACOSX/nih_new/images-small/._00012609_000.png
# __MACOSX/nih_new/images-small/._00030541_005.png
# __MACOSX/nih_new/images-small/._00021195_000.png
# __MACOSX/nih_new/images-small/._00018778_003.png
# __MACOSX/nih_new/images-small/._00011598_037.png
# __MACOSX/nih_new/images-small/._00022248_000.png
# __MACOSX/nih_new/images-small/._00006426_000.png
# __MACOSX/nih_new/images-small/._00001170_045.png
# __MACOSX/nih_new/images-small/._00016052_013.png
# __MACOSX/nih_new/images-small/._00017985_004.png
# __MACOSX/nih_new/images-small/._00012904_002.png
# __MACOSX/nih_new/images-small/._00019767_004.png
# __MACOSX/nih_new/images-small/._00003353_004.png
# __MACOSX/nih_new/images-small/._00013003_038.png
# __MACOSX/nih_new/images-small/._00026505_000.png
# __MACOSX/nih_new/images-small/._00009368_008.png
# __MACOSX/nih_new/images-small/._00011167_011.png
# __MACOSX/nih_new/images-small/._00000359_010.png
# __MACOSX/nih_new/images-small/._00021759_019.png
# __MACOSX/nih_new/images-small/._00011583_008.png
# __MACOSX/nih_new/images-small/._00016595_000.png
# __MACOSX/nih_new/images-small/._00026825_012.png
# __MACOSX/nih_new/images-small/._00022559_003.png
# __MACOSX/nih_new/images-small/._00028574_000.png
# __MACOSX/nih_new/images-small/._00019124_027.png
# __MACOSX/nih_new/images-small/._00001711_000.png
# __MACOSX/nih_new/images-small/._00000459_044.png
# __MACOSX/nih_new/images-small/._00030061_000.png
# __MACOSX/nih_new/images-small/._00020113_030.png
# __MACOSX/nih_new/images-small/._00021869_000.png
# __MACOSX/nih_new/images-small/._00001232_002.png
# __MACOSX/nih_new/images-small/._00013003_012.png
# __MACOSX/nih_new/images-small/._00007523_009.png
# __MACOSX/nih_new/images-small/._00004858_001.png
# __MACOSX/nih_new/images-small/._00006393_005.png
# __MACOSX/nih_new/images-small/._00001034_002.png
# __MACOSX/nih_new/images-small/._00017243_009.png
# __MACOSX/nih_new/images-small/._00018100_000.png
# __MACOSX/nih_new/images-small/._00007046_009.png
# __MACOSX/nih_new/images-small/._00007109_027.png
# __MACOSX/nih_new/images-small/._00014298_002.png
# __MACOSX/nih_new/images-small/._00011959_010.png
# __MACOSX/nih_new/images-small/._00003034_000.png
# __MACOSX/nih_new/images-small/._00009485_000.png
# __MACOSX/nih_new/images-small/._00019680_002.png
# __MACOSX/nih_new/images-small/._00026576_000.png
# __MACOSX/nih_new/images-small/._00014436_008.png
# __MACOSX/nih_new/images-small/._00014274_008.png
# __MACOSX/nih_new/images-small/._00012060_001.png
# __MACOSX/nih_new/images-small/._00009361_007.png
# __MACOSX/nih_new/images-small/._00027725_021.png
# __MACOSX/nih_new/images-small/._00015915_014.png
# __MACOSX/nih_new/images-small/._00015530_039.png
# __MACOSX/nih_new/images-small/._00011649_005.png
# __MACOSX/nih_new/images-small/._00018917_000.png
# __MACOSX/nih_new/images-small/._00027665_000.png
# __MACOSX/nih_new/images-small/._00003659_012.png
# __MACOSX/nih_new/images-small/._00017098_010.png
# __MACOSX/nih_new/images-small/._00012891_005.png
# __MACOSX/nih_new/images-small/._00005566_004.png
# __MACOSX/nih_new/images-small/._00014758_001.png
# __MACOSX/nih_new/images-small/._00025288_001.png
# __MACOSX/nih_new/images-small/._00019565_000.png
# __MACOSX/nih_new/images-small/._00015647_003.png
# __MACOSX/nih_new/images-small/._00013985_000.png
# __MACOSX/nih_new/images-small/._00016693_001.png
# __MACOSX/nih_new/images-small/._00006575_003.png
# __MACOSX/nih_new/images-small/._00005410_000.png
# __MACOSX/nih_new/images-small/._00015732_035.png
# __MACOSX/nih_new/images-small/._00004839_002.png
# __MACOSX/nih_new/images-small/._00022883_003.png
# __MACOSX/nih_new/images-small/._00019277_000.png
# __MACOSX/nih_new/images-small/._00010897_010.png
# __MACOSX/nih_new/images-small/._00012051_001.png
# __MACOSX/nih_new/images-small/._00009358_001.png
# __MACOSX/nih_new/images-small/._00006480_008.png
# __MACOSX/nih_new/images-small/._00010035_001.png
# __MACOSX/nih_new/images-small/._00001736_027.png
# __MACOSX/nih_new/images-small/._00004787_000.png
# __MACOSX/nih_new/images-small/._00003005_020.png
# __MACOSX/nih_new/images-small/._00026753_012.png
# __MACOSX/nih_new/images-small/._00012834_134.png
# __MACOSX/nih_new/images-small/._00030389_003.png
# __MACOSX/nih_new/images-small/._00019038_005.png
# __MACOSX/nih_new/images-small/._00003574_007.png
# __MACOSX/nih_new/images-small/._00018921_023.png
# __MACOSX/nih_new/images-small/._00013140_001.png
# __MACOSX/nih_new/images-small/._00027455_003.png
# __MACOSX/nih_new/images-small/._00008462_006.png
# __MACOSX/nih_new/images-small/._00028902_005.png
# __MACOSX/nih_new/images-small/._00022484_006.png
# __MACOSX/nih_new/images-small/._00028173_014.png
# __MACOSX/nih_new/images-small/._00005401_000.png
# __MACOSX/nih_new/images-small/._00018705_005.png
# __MACOSX/nih_new/images-small/._00019233_008.png
# __MACOSX/nih_new/images-small/._00020945_006.png
# __MACOSX/nih_new/images-small/._00016784_000.png
# __MACOSX/nih_new/images-small/._00006469_001.png
# __MACOSX/nih_new/images-small/._00002785_004.png
# __MACOSX/nih_new/images-small/._00005694_002.png
# __MACOSX/nih_new/images-small/._00015572_006.png
# __MACOSX/nih_new/images-small/._00016189_001.png
# __MACOSX/nih_new/images-small/._00017944_010.png
# __MACOSX/nih_new/images-small/._00010012_006.png
# __MACOSX/nih_new/images-small/._00018996_009.png
# __MACOSX/nih_new/images-small/._00010994_012.png
# __MACOSX/nih_new/images-small/._00014609_006.png
# __MACOSX/nih_new/images-small/._00026185_004.png
# __MACOSX/nih_new/images-small/._00007439_003.png
# __MACOSX/nih_new/images-small/._00011971_007.png
# __MACOSX/nih_new/images-small/._00019733_003.png
# __MACOSX/nih_new/images-small/._00016747_001.png
# __MACOSX/nih_new/images-small/._00009166_013.png
# __MACOSX/nih_new/images-small/._00011696_003.png
# __MACOSX/nih_new/images-small/._00009375_002.png
# __MACOSX/nih_new/images-small/._00019373_003.png
# __MACOSX/nih_new/images-small/._00009773_000.png
# __MACOSX/nih_new/images-small/._00024130_000.png
# __MACOSX/nih_new/images-small/._00026263_007.png
# __MACOSX/nih_new/images-small/._00001897_001.png
# __MACOSX/nih_new/images-small/._00025457_003.png
# __MACOSX/nih_new/images-small/._00019124_090.png
# __MACOSX/nih_new/images-small/._00005890_004.png
# __MACOSX/nih_new/images-small/._00010332_001.png
# __MACOSX/nih_new/images-small/._00006785_000.png
# __MACOSX/nih_new/images-small/._00027466_010.png
# __MACOSX/nih_new/images-small/._00016975_019.png
# __MACOSX/nih_new/images-small/._00003028_027.png
# __MACOSX/nih_new/images-small/._00016064_014.png
# __MACOSX/nih_new/images-small/._00009507_001.png
# __MACOSX/nih_new/images-small/._00017920_003.png
# __MACOSX/nih_new/images-small/._00002435_008.png
# __MACOSX/nih_new/images-small/._00009940_000.png
# __MACOSX/nih_new/images-small/._00016075_003.png
# __MACOSX/nih_new/images-small/._00026132_026.png
# __MACOSX/nih_new/images-small/._00020657_002.png
# __MACOSX/nih_new/images-small/._00012753_004.png
# __MACOSX/nih_new/images-small/._00012359_002.png
# __MACOSX/nih_new/images-small/._00030496_000.png
# __MACOSX/nih_new/images-small/._00029108_002.png
# __MACOSX/nih_new/images-small/._00013567_000.png
# __MACOSX/nih_new/images-small/._00008059_000.png
# __MACOSX/nih_new/images-small/._00007317_013.png
# __MACOSX/nih_new/images-small/._00013408_006.png
# __MACOSX/nih_new/images-small/._00001113_000.png
# __MACOSX/nih_new/images-small/._00009508_000.png
# __MACOSX/nih_new/images-small/._00003586_000.png
# __MACOSX/nih_new/images-small/._00018989_003.png
# __MACOSX/nih_new/images-small/._00026810_041.png
# __MACOSX/nih_new/images-small/._00006332_008.png
# __MACOSX/nih_new/images-small/._00021127_009.png
# __MACOSX/nih_new/images-small/._00019525_000.png
# __MACOSX/nih_new/images-small/._00007069_000.png
# __MACOSX/nih_new/images-small/._00014125_036.png
# __MACOSX/nih_new/images-small/._00010592_005.png
# __MACOSX/nih_new/images-small/._00004508_014.png
# __MACOSX/nih_new/images-small/._00014635_003.png
# __MACOSX/nih_new/images-small/._00025527_001.png
# __MACOSX/nih_new/images-small/._00026171_005.png
# __MACOSX/nih_new/images-small/._00023069_002.png
# __MACOSX/nih_new/images-small/._00018044_032.png
# __MACOSX/nih_new/images-small/._00012775_000.png
# __MACOSX/nih_new/images-small/._00015286_000.png
# __MACOSX/nih_new/images-small/._00001849_000.png
# __MACOSX/nih_new/images-small/._00007906_000.png
# __MACOSX/nih_new/images-small/._00012379_000.png
# __MACOSX/nih_new/images-small/._00027346_000.png
# __MACOSX/nih_new/images-small/._00001212_000.png
# __MACOSX/nih_new/images-small/._00006481_012.png
# __MACOSX/nih_new/images-small/._00029047_000.png
# __MACOSX/nih_new/images-small/._00012819_001.png
# __MACOSX/nih_new/images-small/._00009804_001.png
# __MACOSX/nih_new/images-small/._00012640_018.png
# __MACOSX/nih_new/images-small/._00019605_001.png
# __MACOSX/nih_new/images-small/._00000099_013.png
# __MACOSX/nih_new/images-small/._00010790_032.png
# __MACOSX/nih_new/images-small/._00029981_009.png
# __MACOSX/nih_new/images-small/._00019470_001.png
# __MACOSX/nih_new/images-small/._00019192_000.png
# __MACOSX/nih_new/images-small/._00028264_000.png
# __MACOSX/nih_new/images-small/._00018660_001.png
# __MACOSX/nih_new/images-small/._00010741_009.png
# __MACOSX/nih_new/images-small/._00000589_000.png
# __MACOSX/nih_new/images-small/._00030629_002.png
# __MACOSX/nih_new/images-small/._00016716_010.png
# __MACOSX/nih_new/images-small/._00005916_001.png
# __MACOSX/nih_new/images-small/._00019471_000.png
# __MACOSX/nih_new/images-small/._00027652_000.png
# __MACOSX/nih_new/images-small/._00004747_000.png
# __MACOSX/nih_new/images-small/._00027092_002.png
# __MACOSX/nih_new/images-small/._00011558_002.png
# __MACOSX/nih_new/images-small/._00017236_021.png
# __MACOSX/nih_new/images-small/._00011873_002.png
# __MACOSX/nih_new/images-small/._00014022_085.png
# __MACOSX/nih_new/images-small/._00029830_000.png
# __MACOSX/nih_new/images-small/._00026604_004.png
# __MACOSX/nih_new/images-small/._00014618_011.png
# __MACOSX/nih_new/images-small/._00014465_002.png
# __MACOSX/nih_new/images-small/._00019615_000.png
# __MACOSX/nih_new/images-small/._00013904_014.png
# __MACOSX/nih_new/images-small/._00008081_005.png
# __MACOSX/nih_new/images-small/._00014716_012.png
# __MACOSX/nih_new/images-small/._00009606_010.png
# __MACOSX/nih_new/images-small/._00015056_005.png
# __MACOSX/nih_new/images-small/._00013641_034.png
# ...
# nih_new/images-small/00016983_000.png
# nih_new/images-small/00020213_003.png
# nih_new/images-small/00028682_001.png
# nih_new/images-small/00013003_040.png
# nih_new/images-small/00012874_032.png
# nih_new/images-small/00006031_001.png
# nih_new/images-small/00003395_007.png
# nih_new/images-small/00027477_000.png
# nih_new/images-small/00001107_002.png
# nih_new/images-small/00004992_012.png
# nih_new/images-small/00028876_048.png
# nih_new/images-small/00025295_004.png
# nih_new/images-small/00020052_002.png
# nih_new/images-small/00025971_003.png
# nih_new/images-small/00027355_005.png
# nih_new/images-small/00008068_005.png
# nih_new/images-small/00001385_019.png
# nih_new/images-small/00026641_008.png
# nih_new/images-small/00015732_027.png
# nih_new/images-small/00026964_000.png
# nih_new/images-small/00012276_018.png
# nih_new/images-small/00013655_007.png
# nih_new/images-small/00017691_003.png
# nih_new/images-small/00021818_025.png
# nih_new/images-small/00020819_016.png
# nih_new/images-small/00019870_002.png
# nih_new/images-small/00026685_000.png
# nih_new/images-small/00006851_034.png
# nih_new/images-small/00008081_019.png
# nih_new/images-small/00014022_002.png
# nih_new/images-small/00023967_000.png
# nih_new/images-small/00012161_000.png
# nih_new/images-small/00011269_008.png
# nih_new/images-small/00030340_001.png
# nih_new/images-small/00013641_048.png
# nih_new/images-small/00004497_003.png
# nih_new/images-small/00006039_009.png
# nih_new/images-small/00021982_005.png
# nih_new/images-small/00008745_030.png
# nih_new/images-small/00018855_000.png
# nih_new/images-small/00027486_000.png
# nih_new/images-small/00004735_008.png
# nih_new/images-small/00005746_005.png
# nih_new/images-small/00001190_000.png
# nih_new/images-small/00015647_022.png
# nih_new/images-small/00027287_001.png
# nih_new/images-small/00011054_000.png
# nih_new/images-small/00017731_017.png
# nih_new/images-small/00014758_002.png
# nih_new/images-small/00021449_007.png
# nih_new/images-small/00001836_090.png
# nih_new/images-small/00000640_001.png
# nih_new/images-small/00009368_001.png
# nih_new/images-small/00029808_000.png
# nih_new/images-small/00026451_009.png
# nih_new/images-small/00017549_001.png
# nih_new/images-small/00006104_000.png
# nih_new/images-small/00018000_002.png
# nih_new/images-small/00006297_003.png
# nih_new/images-small/00028871_001.png
# nih_new/images-small/00005132_000.png
# nih_new/images-small/00027863_001.png
# nih_new/images-small/00021489_003.png
# nih_new/images-small/00017158_032.png
# nih_new/images-small/00009807_003.png
# nih_new/images-small/00026810_046.png
# nih_new/images-small/00029682_000.png
# nih_new/images-small/00011211_005.png
# nih_new/images-small/00022883_013.png
# nih_new/images-small/00024597_000.png
# nih_new/images-small/00017819_010.png
# nih_new/images-small/00003523_031.png
# nih_new/images-small/00016109_000.png
# nih_new/images-small/00021293_000.png
# nih_new/images-small/00014798_004.png
# nih_new/images-small/00012707_000.png
# nih_new/images-small/00011770_001.png
# nih_new/images-small/00023154_002.png
# nih_new/images-small/00003552_002.png
# nih_new/images-small/00003868_008.png
# nih_new/images-small/00002661_002.png
# nih_new/images-small/00020213_036.png
# nih_new/images-small/00025081_010.png
# nih_new/images-small/00011852_000.png
# nih_new/images-small/00021653_000.png
# nih_new/images-small/00013685_028.png
# nih_new/images-small/00004523_003.png
# nih_new/images-small/00028844_034.png
# nih_new/images-small/00021201_092.png
# nih_new/images-small/00025613_000.png
# nih_new/images-small/00021338_000.png
# nih_new/images-small/00024560_000.png
# nih_new/images-small/00002704_004.png
# nih_new/images-small/00021616_001.png
# nih_new/images-small/00002743_001.png
# nih_new/images-small/00014677_008.png
# nih_new/images-small/00005416_001.png
# nih_new/images-small/00023116_004.png
# nih_new/images-small/00011355_002.png
# nih_new/images-small/00027213_002.png
# nih_new/images-small/00008975_004.png
# nih_new/images-small/00027592_017.png
# nih_new/images-small/00006799_002.png
# nih_new/images-small/00018494_007.png
# nih_new/images-small/00016604_000.png
# nih_new/images-small/00011156_003.png
# nih_new/images-small/00010582_001.png
# nih_new/images-small/00009365_028.png
# nih_new/images-small/00013931_000.png
# nih_new/images-small/00027685_005.png
# nih_new/images-small/00010294_010.png
# nih_new/images-small/00012363_002.png
# nih_new/images-small/00000248_021.png
# nih_new/images-small/00007735_038.png
# nih_new/images-small/00017135_000.png
# nih_new/images-small/00012722_003.png
# nih_new/images-small/00010535_012.png
# nih_new/images-small/00028304_000.png
# nih_new/images-small/00000032_039.png
# nih_new/images-small/00027888_000.png
# nih_new/images-small/00010428_002.png
# nih_new/images-small/00026997_000.png
# nih_new/images-small/00009701_000.png
# nih_new/images-small/00030652_001.png
# nih_new/images-small/00015214_013.png
# nih_new/images-small/00014015_006.png
# nih_new/images-small/00008171_000.png
# nih_new/images-small/00026469_006.png
# nih_new/images-small/00006551_000.png
# nih_new/images-small/00006585_009.png
# nih_new/images-small/00023128_001.png
# nih_new/images-small/00001663_001.png
# nih_new/images-small/00000772_001.png
# nih_new/images-small/00018013_004.png
# nih_new/images-small/00030323_015.png
# nih_new/images-small/00006434_000.png
# nih_new/images-small/00006272_000.png
# nih_new/images-small/00017126_000.png
# nih_new/images-small/00026925_027.png
# nih_new/images-small/00005309_000.png
# nih_new/images-small/00016036_001.png
# nih_new/images-small/00021509_000.png
# nih_new/images-small/00008727_009.png
# nih_new/images-small/00025703_000.png
# nih_new/images-small/00003481_001.png
# nih_new/images-small/00020290_004.png
# nih_new/images-small/00021463_001.png
# nih_new/images-small/00020915_000.png
# nih_new/images-small/00027299_004.png
# nih_new/images-small/00020517_002.png
# nih_new/images-small/00013209_020.png
# nih_new/images-small/00023696_007.png
# nih_new/images-small/00002491_001.png
# nih_new/images-small/00022093_001.png
# nih_new/images-small/00012043_016.png
# nih_new/images-small/00026889_000.png
# nih_new/images-small/00010390_004.png
# nih_new/images-small/00021128_003.png
# nih_new/images-small/00011544_020.png
# nih_new/images-small/00026050_004.png
# nih_new/images-small/00018512_000.png
# nih_new/images-small/00017702_000.png
# nih_new/images-small/00001373_030.png
# nih_new/images-small/00020076_002.png
# nih_new/images-small/00007670_041.png
# nih_new/images-small/00019733_002.png
# nih_new/images-small/00013950_007.png
# nih_new/images-small/00021772_006.png
# nih_new/images-small/00027260_017.png
# nih_new/images-small/00008010_000.png
# nih_new/images-small/00001701_000.png
# nih_new/images-small/00013249_033.png
# nih_new/images-small/00006944_002.png
# nih_new/images-small/00019059_001.png
# nih_new/images-small/00022785_001.png
# nih_new/images-small/00018724_003.png
# nih_new/images-small/00027912_004.png
# nih_new/images-small/00028606_003.png
# nih_new/images-small/00029570_002.png
# nih_new/images-small/00008760_004.png
# nih_new/images-small/00028285_000.png
# nih_new/images-small/00025650_007.png
# nih_new/images-small/00007873_000.png
# nih_new/images-small/00027464_011.png
# nih_new/images-small/00008368_000.png
# nih_new/images-small/00010808_008.png
# nih_new/images-small/00000798_010.png
# nih_new/images-small/00022526_008.png
# nih_new/images-small/00008348_002.png
# nih_new/images-small/00012884_002.png
# nih_new/images-small/00023283_016.png
# nih_new/images-small/00014981_002.png
# nih_new/images-small/00015756_001.png
# nih_new/images-small/00018661_003.png
# nih_new/images-small/00013572_007.png
# nih_new/images-small/00023296_003.png
# nih_new/images-small/00015003_000.png
# nih_new/images-small/00008508_004.png
# nih_new/images-small/00022870_015.png
# nih_new/images-small/00016480_006.png
# nih_new/images-small/00020458_015.png
# nih_new/images-small/00018627_001.png
# nih_new/images-small/00006906_022.png
# nih_new/images-small/00005983_000.png
# nih_new/images-small/00002796_001.png
# nih_new/images-small/00006634_006.png
# nih_new/images-small/00027282_004.png
# nih_new/images-small/00001986_001.png
# nih_new/images-small/00001430_001.png
# nih_new/images-small/00023128_009.png
# nih_new/images-small/00017645_002.png
# nih_new/images-small/00014296_003.png
# nih_new/images-small/00017807_002.png
# nih_new/images-small/00030024_000.png
# nih_new/images-small/00019708_000.png
# nih_new/images-small/00005094_016.png
# nih_new/images-small/00009507_004.png
# nih_new/images-small/00010967_011.png
# nih_new/images-small/00006436_006.png
# nih_new/images-small/00020240_001.png
# nih_new/images-small/00026494_000.png
# nih_new/images-small/00003863_005.png
# nih_new/images-small/00001610_001.png
# nih_new/images-small/00008515_006.png
# nih_new/images-small/00006021_000.png
# nih_new/images-small/00007468_000.png
# nih_new/images-small/00012094_045.png
# nih_new/images-small/00013229_008.png
# nih_new/images-small/00029165_002.png
# nih_new/images-small/00010294_027.png
# nih_new/images-small/00013625_044.png
# nih_new/images-small/00009562_003.png
# nih_new/images-small/00005646_004.png
# nih_new/images-small/00007828_000.png
# nih_new/images-small/00010758_004.png
# nih_new/images-small/00001437_019.png
# nih_new/images-small/00016657_000.png
# nih_new/images-small/00013278_000.png
# nih_new/images-small/00023276_001.png
# nih_new/images-small/00003670_005.png
# nih_new/images-small/00020846_001.png
# nih_new/images-small/00008328_000.png
# nih_new/images-small/00017470_002.png
# nih_new/images-small/00023158_002.png
# nih_new/images-small/00021179_001.png
# nih_new/images-small/00019333_002.png
# nih_new/images-small/00003534_024.png
# nih_new/images-small/00014320_047.png
# nih_new/images-small/00011391_024.png
# nih_new/images-small/00003752_004.png
# nih_new/images-small/00003675_000.png
# nih_new/images-small/00018958_006.png
# nih_new/images-small/00016860_000.png
# nih_new/images-small/00029091_000.png
# nih_new/images-small/00016410_018.png
# nih_new/images-small/00007390_002.png
# nih_new/images-small/00011493_003.png
# nih_new/images-small/00027631_002.png
# nih_new/images-small/00001659_000.png
# nih_new/images-small/00009798_013.png
# nih_new/images-small/00009911_001.png
# nih_new/images-small/00009552_000.png
# nih_new/images-small/00016521_006.png
# nih_new/images-small/00001794_000.png
# nih_new/images-small/00003576_000.png
# nih_new/images-small/00006713_013.png
# nih_new/images-small/00000588_000.png
# nih_new/images-small/00004581_003.png
# nih_new/images-small/00012765_000.png
# nih_new/images-small/00029711_001.png
# nih_new/images-small/00016568_038.png
# nih_new/images-small/00011553_006.png
# nih_new/images-small/00011355_042.png
# nih_new/images-small/00026480_001.png
# nih_new/images-small/00017373_000.png
# nih_new/images-small/00026232_006.png
# nih_new/images-small/00028416_000.png
# nih_new/images-small/00015530_133.png
# nih_new/images-small/00030733_005.png
# nih_new/images-small/00008885_008.png
# nih_new/images-small/00009340_005.png
# nih_new/images-small/00019594_027.png
# nih_new/images-small/00011584_002.png
# nih_new/images-small/00010932_006.png
# nih_new/images-small/00013049_004.png
# nih_new/images-small/00013088_001.png
# nih_new/images-small/00002592_003.png
# nih_new/images-small/00018056_001.png
# nih_new/images-small/00021463_005.png
# nih_new/images-small/00011702_082.png
# nih_new/images-small/00028873_018.png
# nih_new/images-small/00001749_000.png
# nih_new/images-small/00010497_000.png
# nih_new/images-small/00002478_000.png
# nih_new/images-small/00002474_004.png
# nih_new/images-small/00010007_139.png
# nih_new/images-small/00020738_001.png
# nih_new/images-small/00022717_002.png
# nih_new/images-small/00024175_002.png
# nih_new/images-small/00006868_009.png
# nih_new/images-small/00025383_000.png
# nih_new/images-small/00016094_001.png
# nih_new/images-small/00029244_000.png
# nih_new/images-small/00019406_001.png
# nih_new/images-small/00011567_001.png
# nih_new/images-small/00012176_004.png
# nih_new/images-small/00000678_000.png
# nih_new/images-small/00016092_003.png
# nih_new/images-small/00000832_008.png
# nih_new/images-small/00017508_000.png
# nih_new/images-small/00025527_000.png
# nih_new/images-small/00004872_000.png
# nih_new/images-small/00024474_000.png
# nih_new/images-small/00017423_004.png
# nih_new/images-small/00000865_011.png
# nih_new/images-small/00009245_001.png
# nih_new/images-small/00009326_001.png
# nih_new/images-small/00019521_003.png
# nih_new/images-small/00001872_012.png
# nih_new/images-small/00014911_005.png
# nih_new/images-small/00009727_039.png
# nih_new/images-small/00029863_018.png
# nih_new/images-small/00015360_006.png
# nih_new/images-small/00020277_003.png
# nih_new/images-small/00027594_002.png
# nih_new/images-small/00027833_006.png
# nih_new/images-small/00013603_000.png
# nih_new/images-small/00012233_002.png
# nih_new/images-small/00027202_000.png
# nih_new/images-small/00008841_044.png
# nih_new/images-small/00007958_000.png
# nih_new/images-small/00010888_004.png
# nih_new/images-small/00015498_002.png
# nih_new/images-small/00010334_002.png
# nih_new/images-small/00010651_000.png
# nih_new/images-small/00030415_000.png
# nih_new/images-small/00028766_000.png
# nih_new/images-small/00014134_000.png
# nih_new/images-small/00026489_000.png
# nih_new/images-small/00012019_000.png
# nih_new/images-small/00019635_005.png
# nih_new/images-small/00010272_001.png
# nih_new/images-small/00007894_001.png
# nih_new/images-small/00007141_000.png
# nih_new/images-small/00000552_001.png
# nih_new/images-small/00025664_015.png
# nih_new/images-small/00008291_018.png
# nih_new/images-small/00012993_014.png
# nih_new/images-small/00009912_008.png
# nih_new/images-small/00000634_000.png
# nih_new/images-small/00011420_023.png
# nih_new/images-small/00016882_004.png
# nih_new/images-small/00008741_009.png
# nih_new/images-small/00008981_003.png
# nih_new/images-small/00025746_014.png
# nih_new/images-small/00017753_024.png
# nih_new/images-small/00002846_009.png
# nih_new/images-small/00004270_000.png
# nih_new/images-small/00018546_005.png
# nih_new/images-small/00027618_005.png
# nih_new/images-small/00000315_004.png
# nih_new/images-small/00005986_010.png
# nih_new/images-small/00019899_018.png
# nih_new/images-small/00018187_031.png
# nih_new/images-small/00029188_001.png
# nih_new/images-small/00028844_012.png
# nih_new/images-small/00005832_038.png
# nih_new/images-small/00030023_005.png
# nih_new/images-small/00026793_002.png
# nih_new/images-small/00002721_001.png
# nih_new/images-small/00014107_000.png
# nih_new/images-small/00009826_004.png
# nih_new/images-small/00009185_006.png
# nih_new/images-small/00025628_006.png
# nih_new/images-small/00022125_001.png
# nih_new/images-small/00005231_002.png
# nih_new/images-small/00029861_003.png
# nih_new/images-small/00019469_000.png
# nih_new/images-small/00021114_004.png
# nih_new/images-small/00015628_007.png
# nih_new/images-small/00011251_021.png
# nih_new/images-small/00011713_000.png
# nih_new/images-small/00003489_005.png
# nih_new/images-small/00007687_001.png
# nih_new/images-small/00006043_000.png
# nih_new/images-small/00019861_004.png
# nih_new/images-small/00000940_000.png
# nih_new/images-small/00001831_000.png
# nih_new/images-small/00012413_011.png
# nih_new/images-small/00001301_035.png
# nih_new/images-small/00012777_005.png
# nih_new/images-small/00022458_008.png
# nih_new/images-small/00010524_001.png
# nih_new/images-small/00019528_004.png
# nih_new/images-small/00018860_015.png
# nih_new/images-small/00026500_000.png
# nih_new/images-small/00022260_001.png
# nih_new/images-small/00028591_004.png
# nih_new/images-small/00030082_000.png
# nih_new/images-small/00025754_015.png
# nih_new/images-small/00012505_000.png
# nih_new/images-small/00001855_037.png
# nih_new/images-small/00016258_007.png
# nih_new/images-small/00019847_000.png
# nih_new/images-small/00005089_043.png
# nih_new/images-small/00019962_002.png
# nih_new/images-small/00014197_007.png
# nih_new/images-small/00006926_015.png
# nih_new/images-small/00007510_000.png
# nih_new/images-small/00009446_006.png
# nih_new/images-small/00002898_002.png
# nih_new/images-small/00026497_001.png
# nih_new/images-small/00010433_011.png
# nih_new/images-small/00009953_012.png
# nih_new/test.csv
# nih_new/train-all.csv
# nih_new/data.tar.gz
# nih_new/train-small.csv
# nih_new/train-toy.csv
# nih_new/.DS_Store
# nih_new/pretrained_model.h5
# nih_new/train-small-new.csv
# nih_new/images-small.zip
# nih_new/valid-toy.csv
# reference_cam.npy
# util.py

# %%
# !tar cvfz allfiles.tar.gz *
